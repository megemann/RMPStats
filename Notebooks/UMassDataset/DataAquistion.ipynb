# %%
import requests
    
r = requests.get('https://www.ratemyprofessors.com/professor/2936075')
print(r.text)
# Out:
#     <!DOCTYPE html>
#     <!-- SSR -->
#     <html >
#       <head>
#         <meta name="viewport" content="width=device-width, initial-scale=1" />
#         <meta name="theme-color" content="#000000" />
#         <meta name="thumbnail" content="https://www.ratemyprofessors.com/build/thumbnail.svg" />
#
#
#
#         <link rel="manifest" href="/build/manifest.json">
#         <link rel="stylesheet" type="text/css" href="/static/css/main.1773c5b7.css">
#
#         <!-- Nobid Prebid Wrapper -->
#         <script async id="nobid-wrapper" src="https://public.servenobid.com/partner/66897/56514/wrapup_1.0.2.js"></script>
#         <script>
#           window.wrapup = window.wrapup || { cmd: [] };
#         </script>
#
#         <link data-react-helmet="true" rel="icon" href="/favicons/favicon-16.png" sizes/><link data-react-helmet="true" rel="icon" href="/favicons/favicon-32.png" sizes="32×32"/><link data-react-helmet="true" rel="apple-touch-icon" href="/favicons/favicon-57.png" sizes/><link data-react-helmet="true" rel="apple-touch-icon" href="/favicons/favicon-48.png" sizes="48×48"/><link data-react-helmet="true" rel="apple-touch-icon" href="/favicons/favicon-72.png" sizes="72×72"/><link data-react-helmet="true" rel="apple-touch-icon" href="/favicons/favicon-114.png" sizes="114×114"/><link data-react-helmet="true" rel="apple-touch-icon" href="/favicons/favicon-152.png" sizes="152×152"/><link data-react-helmet="true" rel="apple-touch-icon-precomposed" href="/favicons/favicon-196.png" sizes/><link data-react-helmet="true" rel="canonical" href/>
# <title data-react-helmet="true">Mark Wilson at University of Massachusetts - Amherst | Rate My Professors</title>
# <meta data-react-helmet="true" property="og:image" content="/static/media/meta-no-thumbs.16c7cf81.png"/><meta data-react-helmet="true" property="og:type" content="website"/><meta data-react-helmet="true" name="twitter:card" content="summary_large_image"/><meta data-react-helmet="true" name="fo-verify" content="0ab72f55-ad7d-4d15-9196-2791be44b44c"/><meta data-react-helmet="true" name="title" content="Mark Wilson at University of Massachusetts - Amherst | Rate My Professors"/><meta data-react-helmet="true" name="description" content="Mark Wilson  is a professor in the Computer Science department at University of Massachusetts - Amherst - see what their students are saying about them or leave a rating yourself."/><meta data-react-helmet="true" property="og:url" content/><meta data-react-helmet="true" property="og:title" content="Mark Wilson at University of Massachusetts - Amherst | Rate My Professors"/><meta data-react-helmet="true" property="og:description" content="Mark Wilson  is a professor in the Computer Science department at University of Massachusetts - Amherst - see what their students are saying about them or leave a rating yourself."/>
#
#         <style data-styled="kaBGnN  bhyGpW ducGvC enzK hNQJBj hsMvnW fWcpms kjTgMJ vWase ecMUyP cdrVhb bFAPID bFqXne fiaAxo jBOPiI gmfVsA kljOpt itGGhm bLpdSv gMZkZH jNLsMB hxCzZQ eJRnwy irUZwm ksrzOn koGnqT fwqnjW bIxMQe enwdCS eFXKqj dZykPc eydgty gMXENl fHlqte fsOMKN ftqFWl khahiz bLuxdV bKRBLv gYUKbL kSkwHC dpCfpS gDtLGS iYFgni deMmer eKGsjy iaBBKY egjGwd fSkQCp hVjzhH dTNeOJ lnrRWu fPrYfD cvMijt jSHODG jorcU iICgQL iYlXhw hFWTst kQGiGx gtQHFe frDnMc dftOYg ktnBVh fVZsFn EJltd flKehn kFNvIp gIgExh bIUJtl liyUjw UqFtE eTpHeJ jMkisx cfjPUG erLzyk iLYGwn iMmVHb cxVUGc dTFbKx kkESWs hddnCs dCSpBu EeKLq gXtLCL dpugOF hTvExa hiHJpP kASCrL hjXElA djeIgv fiLOtD hHOVKF kezNwl dwQOEV hKtAQE hGvnQn kgFDnO jSKXed eLbzKR gMAFfH htLcUt exRiLa cVgfSx hnDpZn SlkSm iSLkvi bOzrdx SjINA iOszTt jtpiDd cbdtns jcIQzP dGrvXb iwdCaD jTpfex hrIcnr eXfReS iwwYJD bXQmMr gFOUvY DObVa eWZmyX fVETNc bUneqk cDKJcc icXUyq kEVEoU fPJDHT LXClX hNEpQo gRjWel eLpnFv dbULCX jsOpVQ jLESE bwcdkk biwTxB hZbccg lihvHt cwcCIQ bKmfty cRwVmO hjlYuE kVglhF Jqjub glImpo dBjsXt goPkAd jeWhrO VWyoY kUoclT fxTUTO WZsQZ jJWSqG lmqcKL iWwtwW dAqQLO ivZzTO" data-styled-version="4.4.1">
# /* sc-component-id: PageWrapper__StyledPageWrapper-sc-3p8f0h-0 */
# .ktnBVh{margin-bottom:58px;min-height:calc( 100vh - 240px );overflow-x:hidden;overflow-y:hidden;} @media screen and (min-width:1225px){.ktnBVh{margin:0 auto;max-width:1224px;width:100%;}}
# /* sc-component-id: IconButton__StyledIconButton-eamykg-0 */
# .dpugOF{-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;background:none;border:0;cursor:pointer;display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;outline:none;padding:0;} .dpugOF span{font-family:HelveticaNeue,arial;font-weight:700;margin:0 5px;}
# /* sc-component-id: PaginationButton__StyledPaginationButton-txi1dr-1 */
# .glImpo{background:black;border:1px solid #0021ff;border-radius:100px;color:white;display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;font-stretch:normal;font-weight:700;-webkit-box-pack:center;-webkit-justify-content:center;-ms-flex-pack:center;justify-content:center;-webkit-letter-spacing:normal;-moz-letter-spacing:normal;-ms-letter-spacing:normal;letter-spacing:normal;line-height:1.54;outline:none;padding:11px 46px;-webkit-transition:-webkit-transform 0.2s;-webkit-transition:transform 0.2s;transition:transform 0.2s;margin:40px auto 40px auto;text-align:center;} .glImpo:not(:disabled):hover{-webkit-transform:scale(1.05);-ms-transform:scale(1.05);transform:scale(1.05);} .glImpo:hover{cursor:pointer;} .glImpo:disabled{background:#989898;cursor:not-allowed;} .glImpo::after{-webkit-align-self:center;-ms-flex-item-align:center;align-self:center;background-image:url(/static/media/right-arrow-white.3698faf1.svg);content:'';display:none;height:15px;margin-left:10px;width:15px;} .glImpo .LoadingIcon-sc-1naxssl-0{color:white;}
# /* sc-component-id: Comments__StyledComments-dzzyvm-0 */
# .gRjWel{-webkit-flex:1;-ms-flex:1;flex:1;font-size:16px;line-height:1.5;margin-bottom:30px;}
# /* sc-component-id: ReportFlag__StyledReportFlag-sc-1c42epr-0 */
# .hjlYuE{cursor:pointer;-webkit-text-decoration:none;text-decoration:none;}
# /* sc-component-id: ReportFlag__FlagWrapper-sc-1c42epr-1 */
# .kVglhF{-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;} .kVglhF span{color:#4e4e4e;font-style:italic;padding-right:12px;}
# /* sc-component-id: TimeStamp__StyledTimeStamp-sc-9q2r30-0 */
# .bXQmMr{font-weight:700;padding-bottom:15px;}
# /* sc-component-id: RatingHeader__StyledHeader-sc-1dlkqw1-1 */
# .iwdCaD{-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;display:none;-webkit-box-pack:justify;-webkit-justify-content:space-between;-ms-flex-pack:justify;justify-content:space-between;margin:5px 0 10px;min-height:31px;} @media screen and (max-width:680px){.iwdCaD{-webkit-align-items:flex-start;-webkit-box-align:flex-start;-ms-flex-align:flex-start;align-items:flex-start;margin-bottom:15px;display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;}} .iwdCaD .OnlineCourseLogo__StyledLogo-qyf3kt-0{margin-right:14px;}.jTpfex{-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-box-pack:justify;-webkit-justify-content:space-between;-ms-flex-pack:justify;justify-content:space-between;margin:5px 0 10px;min-height:31px;} @media screen and (max-width:680px){.jTpfex{-webkit-align-items:flex-start;-webkit-box-align:flex-start;-ms-flex-align:flex-start;align-items:flex-start;margin-bottom:15px;display:none;}} .jTpfex .OnlineCourseLogo__StyledLogo-qyf3kt-0{margin-right:14px;}
# /* sc-component-id: RatingHeader__ClassInfoWrapper-sc-1dlkqw1-2 */
# .hrIcnr{display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;} @media screen and (max-width:680px){.hrIcnr{-webkit-flex-direction:column;-ms-flex-direction:column;flex-direction:column;}.hrIcnr .EmotionLabel__StyledEmotionLabel-sc-1u525uj-0{text-align:center;}}
# /* sc-component-id: RatingHeader__StyledClass-sc-1dlkqw1-3 */
# .eXfReS{-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;-webkit-align-self:center;-ms-flex-item-align:center;align-self:center;display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;font-size:16px;padding-right:22px;text-transform:uppercase;font-family:Poppins,sans-serif;font-weight:900;} @media screen and (max-width:680px){.eXfReS{margin-bottom:8px;}}
# /* sc-component-id: RatingHeader__RatingTimeStamp-sc-1dlkqw1-4 */
# .iwwYJD{font-size:14px;padding-bottom:0;}
# /* sc-component-id: CardNumRating__StyledCardNumRating-sc-17t4b9u-0 */
# .eWZmyX{display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-flex-direction:column;-ms-flex-direction:column;flex-direction:column;}
# /* sc-component-id: CardNumRating__CardNumRatingHeader-sc-17t4b9u-1 */
# .fVETNc{font-size:12px;font-weight:600;line-height:14px;margin-bottom:4px;text-transform:uppercase;}
# /* sc-component-id: CardNumRating__CardNumRatingNumber-sc-17t4b9u-2 */
# .bUneqk{-webkit-align-self:center;-ms-flex-item-align:center;align-self:center;background:#ff9c9c;height:64px;line-height:36px;margin-bottom:8px;padding:14px 10px;width:72px;font-size:32px;font-family:Poppins,sans-serif;font-weight:900;}.cDKJcc{-webkit-align-self:center;-ms-flex-item-align:center;align-self:center;background:#e4e4e4;height:64px;line-height:36px;margin-bottom:8px;padding:14px 10px;width:72px;font-size:32px;font-family:Poppins,sans-serif;font-weight:900;}.icXUyq{-webkit-align-self:center;-ms-flex-item-align:center;align-self:center;background:#fff170;height:64px;line-height:36px;margin-bottom:8px;padding:14px 10px;width:72px;font-size:32px;font-family:Poppins,sans-serif;font-weight:900;}
# /* sc-component-id: RatingValues__StyledRatingValues-sc-6dc747-0 */
# .gFOUvY{display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-flex-direction:column;-ms-flex-direction:column;flex-direction:column;} @media screen and (max-width:680px){.gFOUvY{-webkit-flex-direction:row;-ms-flex-direction:row;flex-direction:row;}} .gFOUvY .CardNumRating__CardNumRatingHeader-sc-17t4b9u-1{font-size:14px;}
# /* sc-component-id: RatingValues__RatingContainer-sc-6dc747-1 */
# .DObVa{margin-bottom:24px;} @media screen and (max-width:680px){.DObVa{margin:0 29px 23px 0;}}
# /* sc-component-id: MetaItem__StyledMetaItem-y0ixml-0 */
# .LXClX{font-size:16px;line-height:1.54;margin-right:16px;padding:4px 0;white-space:nowrap;} @media screen and (max-width:680px){.LXClX{font-size:14px;}} .LXClX span{font-weight:700;}
# /* sc-component-id: CourseMeta__StyledCourseMeta-x344ms-0 */
# .fPJDHT{display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-flex-flow:wrap;-ms-flex-flow:wrap;flex-flow:wrap;margin-bottom:14px;} @media screen and (max-width:680px){.fPJDHT{-webkit-flex-flow:column;-ms-flex-flow:column;flex-flow:column;}} .fPJDHT .MetaItem__StyledMetaItem-y0ixml-0{margin-bottom:8px;}
# /* sc-component-id: Tag-bs9vf4-0 */
# .hHOVKF{background-color:#f1f1f1;border-radius:14.5px;font-stretch:condensed;margin:0 16px 8px 0;padding:8px 16px;text-align:center;text-transform:uppercase;font-family:HelveticaNeue,arial;font-weight:700;}
# /* sc-component-id: RatingTags__StyledTags-sc-1boeqx2-0 */
# .eLpnFv{display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-flex-wrap:wrap;-ms-flex-wrap:wrap;flex-wrap:wrap;margin-bottom:12px;}
# /* sc-component-id: Tooltip__StyledTooltip-znwb87-0 */
# .kSkwHC{background:#151515;border-radius:6px;box-shadow:0px 4px 4px rgba(126,126,126,0.25);color:white;display:block;font-family:HelveticaNeue,arial;font-size:13px;-webkit-letter-spacing:0.5px;-moz-letter-spacing:0.5px;-ms-letter-spacing:0.5px;letter-spacing:0.5px;line-height:15px;margin-top:15px;opacity:0.9;padding:12px 16px;}
# /* sc-component-id: VoteThumb__StyledVoteThumb-p2gtch-0 */
# .hZbccg{margin-right:5px;}
# /* sc-component-id: VoteThumb__StyledVoteContainer-p2gtch-1 */
# .bwcdkk{-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;cursor:default;display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;}
# /* sc-component-id: VoteThumb__HelpfulText-p2gtch-2 */
# .biwTxB{color:#000000;margin-right:5px;}
# /* sc-component-id: Thumbs__ButtonWrapper-sc-19shlav-0 */
# .jsOpVQ{-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;}
# /* sc-component-id: Thumbs__ThumbContainer-sc-19shlav-1 */
# .jLESE{display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-flex-direction:row;-ms-flex-direction:row;flex-direction:row;font-weight:700;margin-right:16px;} .jLESE img{height:22px;}
# /* sc-component-id: Thumbs__HelpTotalNumber-sc-19shlav-2 */
# .lihvHt{font-size:16px;margin-top:5px;}
# /* sc-component-id: ShareRating__StyledShareRating-sc-2mgjp4-0 */
# .bKmfty{cursor:pointer;-webkit-text-decoration:none;text-decoration:none;}
# /* sc-component-id: ShareRating__ShareWrapper-sc-2mgjp4-1 */
# .cRwVmO{-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;} .cRwVmO span{color:#4e4e4e;font-style:italic;padding-right:12px;}
# /* sc-component-id: RatingFooter__StyledRatingFooter-ciwspm-0 */
# .dbULCX{display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-box-pack:justify;-webkit-justify-content:space-between;-ms-flex-pack:justify;justify-content:space-between;margin:24px 0 32px;}
# /* sc-component-id: RatingFooter__ButtonWrapper-ciwspm-1 */
# .cwcCIQ{-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;}
# /* sc-component-id: Rating__RatingBody-sc-1rhvpxz-0 */
# .dGrvXb{display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;padding:21px 24px 0;} @media screen and (max-width:680px){.dGrvXb{-webkit-flex-direction:column;-ms-flex-direction:column;flex-direction:column;}}
# /* sc-component-id: Rating__StyledRating-sc-1rhvpxz-1 */
# .jcIQzP{background-color:rgba(241,241,241,0.4);margin:16px 0;}
# /* sc-component-id: Rating__RatingComments-sc-1rhvpxz-2 */
# .hNEpQo{font-size:16px;line-height:1.5;margin-bottom:30px;}
# /* sc-component-id: Rating__RatingInfo-sc-1rhvpxz-3 */
# .kEVEoU{display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-flex-direction:column;-ms-flex-direction:column;flex-direction:column;margin-left:48px;text-align:left;width:100%;} @media screen and (max-width:680px){.kEVEoU{margin:0;}}
# /* sc-component-id: AdNoBid__AdNoBidLeaderboardStyled-sc-7ofdbw-0 */
# .dftOYg{display:grid;-webkit-box-pack:left;-webkit-justify-content:left;-ms-flex-pack:left;justify-content:left;margin-bottom:16px;} @media screen and (max-width:984px){.dftOYg{-webkit-box-pack:center;-webkit-justify-content:center;-ms-flex-pack:center;justify-content:center;}}
# /* sc-component-id: RatingsList__RatingsUL-hn9one-0 */
# .cbdtns{list-style:none;}
# /* sc-component-id: JumpToRatings__StyledJumpToRatings-sc-1v42jg0-0 */
# .eTpHeJ{display:none;font-size:12px;font-weight:700;height:100%;-webkit-text-decoration:none;text-decoration:none;} @media screen and (max-width:984px){.eTpHeJ{display:block;}}
# /* sc-component-id: RatingValue__NumRatings-qw8sqy-0 */
# .jMkisx{margin-bottom:25px;padding-top:10px;font-family:Poppins,sans-serif;font-weight:700;} .jMkisx a{color:#151515;}
# /* sc-component-id: RatingValue__AvgRating-qw8sqy-1 */
# .gIgExh{display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-box-pack:justify;-webkit-justify-content:space-between;-ms-flex-pack:justify;justify-content:space-between;}
# /* sc-component-id: RatingValue__Numerator-qw8sqy-2 */
# .liyUjw{font-size:80px;margin-right:11px;font-family:Poppins,sans-serif;font-weight:900;} @media screen and (max-width:1224px){.liyUjw{font-size:60px;}}
# /* sc-component-id: RatingValue__AvgRatingWrapper-qw8sqy-3 */
# .bIUJtl{display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;}
# /* sc-component-id: RatingValue__Denominator-qw8sqy-4 */
# .UqFtE{color:#989898;font-size:18px;font-weight:700;position:relative;top:15px;} @media screen and (max-width:1224px){.UqFtE{top:7px;}}
# /* sc-component-id: TeacherBookmark__StyledTeacherBookmark-sc-17dr6wh-0 */
# .hVjzhH{background:none;border:0;cursor:default;height:-webkit-fit-content;height:-moz-fit-content;height:fit-content;outline:none;padding:0;width:-webkit-fit-content;width:-moz-fit-content;width:fit-content;}
# /* sc-component-id: TeacherDepartment__StyledDepartmentLink-fl79e8-0 */
# .iMmVHb{color:#151515;font-weight:bold;}
# /* sc-component-id: NameTitle__Name-dowf0z-0 */
# .cfjPUG{font-size:40px;-webkit-hyphens:auto;-moz-hyphens:auto;-ms-hyphens:auto;hyphens:auto;overflow-wrap:break-word;padding-bottom:10px;word-break:break-word;font-family:Poppins,sans-serif;font-weight:900;} .cfjPUG .TeacherBookmark__StyledTeacherBookmark-sc-17dr6wh-0{margin-left:8px;} .cfjPUG .TeacherBookmark__StyledTeacherBookmark-sc-17dr6wh-0 img{height:32px;width:32px;}
# /* sc-component-id: NameTitle__Title-dowf0z-1 */
# .iLYGwn{max-width:100%;padding-bottom:40px;width:330px;} @media screen and (max-width:1224px){.iLYGwn{padding-bottom:24px;}} .iLYGwn .span,.iLYGwn a{font-weight:700;}
# /* sc-component-id: NameTitle__NameWrapper-dowf0z-2 */
# .erLzyk{margin-bottom:0.2em !important;white-space:normal;}
# /* sc-component-id: TeacherTags__TagsContainer-sc-16vmh1y-0 */
# .fiLOtD{display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-flex-wrap:wrap;-ms-flex-wrap:wrap;flex-wrap:wrap;max-width:464px;}
# /* sc-component-id: TeacherTags__TagsHeader-sc-16vmh1y-1 */
# .djeIgv{font-size:16px;padding-bottom:16px;font-size:16px;font-family:Poppins,sans-serif;font-weight:700;}
# /* sc-component-id: TeacherTags__TagsWrapper-sc-16vmh1y-2 */
# @media screen and (max-width:984px){.hjXElA{display:none;}}
# /* sc-component-id: NameLink__StyledNameLink-sc-4u2ek-0 */
# .hiHJpP{display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;} .hiHJpP >:nth-child(1){padding-right:12px;} .hiHJpP >:nth-child(2){border-left:1px solid #151515;padding-left:12px;}
# /* sc-component-id: NameLink__StyledModalLink-sc-4u2ek-2 */
# .kASCrL{cursor:pointer;display:inline-block;font-weight:700;margin-bottom:24px;-webkit-text-decoration:underline;text-decoration:underline;}
# /* sc-component-id: FeedbackItem__StyledFeedbackItem-uof32n-0 */
# .dTFbKx{display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-flex-direction:column;-ms-flex-direction:column;flex-direction:column;text-align:center;}
# /* sc-component-id: FeedbackItem__FeedbackNumber-uof32n-1 */
# .kkESWs{color:#000000;margin-bottom:4px;font-size:32px;font-family:Poppins,sans-serif;font-weight:900;}
# /* sc-component-id: FeedbackItem__FeedbackDescription-uof32n-2 */
# .hddnCs{font-weight:500;}
# /* sc-component-id: TeacherFeedback__StyledTeacherFeedback-gzhlj7-0 */
# .cxVUGc{display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;margin-bottom:25px;} .cxVUGc >:nth-child(1){padding:0 12px 16px 0;} .cxVUGc >:nth-child(2){border-left:1px solid #151515;padding:0 0 16px 12px;}
# /* sc-component-id: TeacherInfo__RateButton-ti1fio-0 */
# .EeKLq{-webkit-text-decoration:none;text-decoration:none;width:-webkit-fit-content;width:-moz-fit-content;width:fit-content;background:#0055fd;border:1px solid #0021ff;border-radius:100px;color:white;display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;font-stretch:normal;font-weight:700;-webkit-box-pack:center;-webkit-justify-content:center;-ms-flex-pack:center;justify-content:center;-webkit-letter-spacing:normal;-moz-letter-spacing:normal;-ms-letter-spacing:normal;letter-spacing:normal;line-height:1.54;outline:none;padding:11px 46px;-webkit-transition:-webkit-transform 0.2s;-webkit-transition:transform 0.2s;transition:transform 0.2s;} .EeKLq:not(:disabled):hover{-webkit-transform:scale(1.05);-ms-transform:scale(1.05);transform:scale(1.05);} .EeKLq:hover{cursor:pointer;} .EeKLq:disabled{background:#989898;cursor:not-allowed;} .EeKLq::after{-webkit-align-self:center;-ms-flex-item-align:center;align-self:center;background-image:url(/static/media/right-arrow-white.3698faf1.svg);content:'';display:none;height:15px;margin-left:10px;width:15px;} .EeKLq .LoadingIcon-sc-1naxssl-0{color:white;} .EeKLq:not(:disabled).TeacherInfo__RateButton-ti1fio-0:hover{background:#0021ff;-webkit-transform:none;-ms-transform:none;transform:none;}
# /* sc-component-id: TeacherInfo__StyledTeacher-ti1fio-1 */
# .kFNvIp{-webkit-flex:1 0 40%;-ms-flex:1 0 40%;flex:1 0 40%;padding:22px 0;text-align:left;} @media screen and (max-width:984px){.kFNvIp{padding-right:22px;padding-bottom:25px;}} .kFNvIp .TeacherInfo__RateButton-ti1fio-0{margin-bottom:24px;}
# /* sc-component-id: TeacherInfo__CompareButton-ti1fio-2 */
# .hTvExa{margin-bottom:24px;margin-left:12px;-webkit-text-decoration:none;text-decoration:none;width:-webkit-fit-content;width:-moz-fit-content;width:fit-content;background:#ffffff;border:1px solid #0021ff;border-radius:100px;color:#0021ff;display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;font-stretch:normal;font-weight:700;-webkit-box-pack:center;-webkit-justify-content:center;-ms-flex-pack:center;justify-content:center;-webkit-letter-spacing:normal;-moz-letter-spacing:normal;-ms-letter-spacing:normal;letter-spacing:normal;line-height:1.54;outline:none;padding:11px 46px;-webkit-transition:-webkit-transform 0.2s;-webkit-transition:transform 0.2s;transition:transform 0.2s;} .hTvExa:not(:disabled):hover{-webkit-transform:scale(1.05);-ms-transform:scale(1.05);transform:scale(1.05);} .hTvExa:hover{color:#ffffff;cursor:pointer;} .hTvExa:disabled{background:#989898;cursor:not-allowed;} .hTvExa::after{-webkit-align-self:center;-ms-flex-item-align:center;align-self:center;content:'';display:none;height:15px;margin-left:10px;width:15px;} .hTvExa .LoadingIcon-sc-1naxssl-0{color:white;} @media screen and (max-width:680px){.hTvExa{margin-left:12px;}} .hTvExa:not(:disabled).TeacherInfo__CompareButton-ti1fio-2:hover{background:#0021ff;-webkit-transform:none;-ms-transform:none;transform:none;}
# /* sc-component-id: TeacherInfo__RateIconButton-ti1fio-3 */
# .gXtLCL{color:white;}
# /* sc-component-id: TeacherInfo__InfoButtonContainer-ti1fio-4 */
# .dCSpBu{display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-flex-direction:row;-ms-flex-direction:row;flex-direction:row;-webkit-box-pack:start;-webkit-justify-content:flex-start;-ms-flex-pack:start;justify-content:flex-start;}
# /* sc-component-id: RatingsFilterList__StyledRatingsFilterList-sc-84a4cc-0 */
# .iOszTt{display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;margin-top:16px;width:100%;}
# /* sc-component-id: TeacherRatingTabs__StyledTabs-pnmswv-0 */
# @media screen and (min-width:1225px){.SlkSm{max-width:calc(1224px - 354px);}}
# /* sc-component-id: TeacherRatingTabs__StyledTabList-pnmswv-1 */
# .iSLkvi{border-bottom:2px solid #f1f1f1;display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;margin:28px 22px 0 22px;} @media screen and (max-width:1224px){.iSLkvi{margin:0;}}
# /* sc-component-id: TeacherRatingTabs__StyledTab-pnmswv-2 */
# .bOzrdx{border-bottom:2px solid #151515;color:#151515;cursor:pointer;font-weight:700;line-height:1.8;min-width:150px;padding-bottom:8px;} @media screen and (max-width:1224px){.bOzrdx{font-size:14px;width:100%;}} .bOzrdx:hover{border-bottom:2px solid #989898;color:#989898;}
# /* sc-component-id: TeacherRatingTabs__StyledTabPage-pnmswv-3 */
# .SjINA{padding:0 22px;}
# /* sc-component-id: SimilarProfessorListItem__TeacherScoreSpan-x7cr0c-0 */
# .eLbzKR{-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;background:#0055fd;color:#f1f1f1;display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;font-size:16px;-webkit-box-pack:center;-webkit-justify-content:center;-ms-flex-pack:center;justify-content:center;margin-right:8px;padding:10px 7px;font-family:Poppins,sans-serif;font-weight:900;}
# /* sc-component-id: SimilarProfessorListItem__TeacherNameSpan-x7cr0c-1 */
# .gMAFfH{text-align:left;}
# /* sc-component-id: SimilarProfessorListItem__StyledSimilarProfessorLink-x7cr0c-2 */
# .jSKXed{-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;padding-right:5px;-webkit-text-decoration:none;text-decoration:none;} .jSKXed:hover .SimilarProfessorListItem__TeacherNameSpan-x7cr0c-1{color:#0021ff;} .jSKXed:hover .SimilarProfessorListItem__TeacherScoreSpan-x7cr0c-0{background:#0021ff;}
# /* sc-component-id: SimilarProfessors__SimilarProfessorsTitle-zg1hrt-0 */
# .hGvnQn{font-family:Poppins,sans-serif;font-size:16px;font-weight:600;padding-left:35px;padding-top:15px;text-align:left;}
# /* sc-component-id: SimilarProfessors__StyledSimilarProfessorsList-zg1hrt-1 */
# .kgFDnO{-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-box-pack:space-evenly;-webkit-justify-content:space-evenly;-ms-flex-pack:space-evenly;justify-content:space-evenly;padding-bottom:15px;padding-left:35px;padding-top:15px;width:100%;} @media screen and (max-width:680px){.kgFDnO li:nth-child(3){display:none;}}
# /* sc-component-id: SimilarProfessors__SimilarProfessorsContainer-zg1hrt-2 */
# .hKtAQE{background-color:rgba(217,232,255,0.61);margin-top:17px;width:464px;} @media screen and (max-width:680px){.hKtAQE{width:324px;}}
# /* sc-component-id: AdRail__StyledAdRail-sc-1kamohe-0 */
# .hnDpZn{display:block;-webkit-box-flex:0;-webkit-flex-grow:0;-ms-flex-positive:0;flex-grow:0;margin:0 37px 0 17px;max-height:600px;padding:4px;position:fixed;top:120px;width:308px;z-index:40000;} @media screen and (min-width:1225px){.hnDpZn{margin-left:calc( 1224px - 354px + 17px );}} @media screen and (max-width:1224px){.hnDpZn{width:100%;display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-box-pack:center;-webkit-justify-content:center;-ms-flex-pack:center;justify-content:center;position:static;margin:10px 0;}} .hnDpZn > *{margin-bottom:5px;}
# /* sc-component-id: RatingDistributionWrapper__StyledRatingDistributionWrapper-ku50n8-0 */
# .dwQOEV{background-color:#f7f7f7;height:325px;margin-bottom:24px;width:464px;} @media screen and (max-width:680px){.dwQOEV{width:324px;}}
# /* sc-component-id: JWVideoPlayer__StyledJWWrapper-sc-15sm827-0 */
# @media screen and (max-width:768px){.exRiLa .jw-flag-floating .jw-wrapper{-webkit-transform:none !important;-ms-transform:none !important;transform:none !important;-webkit-transition:none !important;transition:none !important;position:fixed !important;top:0 !important;right:0 !important;left:auto !important;width:100% !important;max-width:264px !important;max-height:164px !important;pointer-events:none;-webkit-user-select:none;-moz-user-select:none;-ms-user-select:none;user-select:none;touch-action:none !important;}.exRiLa .jw-float-bar,.exRiLa .jw-float-icon{display:none !important;}}
# /* sc-component-id: JWVideoPlayer__StyledJWPlayer-sc-15sm827-1 */
# .cVgfSx{position:relative;z-index:50000;}
# /* sc-component-id: AdLeaderboard__StyledAdLeaderboard-sc-1gj31a6-0 */
# .gtQHFe{display:block;text-align:left;width:100%;z-index:210000;} @media screen and (max-width:1280px){.gtQHFe{display:block;margin-left:16px !important;}} @media screen and (max-width:1280px){.gtQHFe{margin:24px 0px 24px 0px;}} @media screen and (max-width:1224px){.gtQHFe{text-align:center;}} @media screen and (min-width:1225px){.gtQHFe{max-width:calc(1224px - 354px);}}
# /* sc-component-id: AdLeaderboard__AdWrapper-sc-1gj31a6-1 */
# .frDnMc{display:inline-block;min-width:100%;}
# /* sc-component-id: AdLeaderboard__StyledWunderkindWrapper-sc-1gj31a6-2 */
# .EJltd{display:inline-block;max-height:250px;max-width:970px;position:relative;}
# /* sc-component-id: TeacherTitles__StyledTeacherTitles-new3kl-0 */
# .lnrRWu{display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-flex-direction:row;-ms-flex-direction:row;flex-direction:row;} @media screen and (max-width:768px){.lnrRWu{-webkit-flex-direction:column;-ms-flex-direction:column;flex-direction:column;padding-bottom:10px;}}
# /* sc-component-id: TeacherTitles__StyledDot-new3kl-1 */
# .cvMijt{font-weight:bold;padding:0 5px;} @media screen and (max-width:768px){.cvMijt{display:none;}}
# /* sc-component-id: TeacherTitles__StyledDepartmentName-new3kl-2 */
# @media screen and (max-width:768px){.fPrYfD{padding-bottom:2px;margin-right:5px;}}
# /* sc-component-id: TeacherTitles__TeacherSchoolLink-new3kl-3 */
# .jSHODG{color:#7E7E7E;}
# /* sc-component-id: HeaderRateButton__StyledRateTeacherButton-rxcxie-0 */
# .iYlXhw{background:#0055fd;border:1px solid #0021ff;border-radius:100px;color:white;display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;font-stretch:normal;font-weight:700;-webkit-box-pack:center;-webkit-justify-content:center;-ms-flex-pack:center;justify-content:center;-webkit-letter-spacing:normal;-moz-letter-spacing:normal;-ms-letter-spacing:normal;letter-spacing:normal;line-height:1.54;outline:none;padding:11px 46px;-webkit-transition:-webkit-transform 0.2s;-webkit-transition:transform 0.2s;transition:transform 0.2s;font-size:16px;min-width:164px;max-width:284px;-webkit-text-decoration:none;text-decoration:none;} .iYlXhw:not(:disabled):hover{-webkit-transform:scale(1.05);-ms-transform:scale(1.05);transform:scale(1.05);} .iYlXhw:hover{cursor:pointer;} .iYlXhw:disabled{background:#989898;cursor:not-allowed;} .iYlXhw::after{-webkit-align-self:center;-ms-flex-item-align:center;align-self:center;background-image:url(/static/media/right-arrow-white.3698faf1.svg);content:'';display:none;height:15px;margin-left:10px;width:15px;} .iYlXhw .LoadingIcon-sc-1naxssl-0{color:white;} @media screen and (max-width:1224px){} @media screen and (max-width:768px){.iYlXhw{min-width:175px;margin-top:0px;}} @media screen and (max-width:680px){.iYlXhw{max-width:100%;}} .iYlXhw:not(:disabled).HeaderRateButton__StyledRateTeacherButton-rxcxie-0:hover{background:#0021ff;-webkit-transform:none;-ms-transform:none;transform:none;} .iYlXhw:not(:disabled).HeaderRateButton__StyledRateTeacherButton-rxcxie-0:hover{background:#0021ff;-webkit-transform:none;-ms-transform:none;transform:none;}
# /* sc-component-id: HeaderRateButton__StyledCompareProfessorButton-rxcxie-1 */
# .hFWTst{background:#ffffff;border:1px solid #0021ff;border-radius:100px;color:#0021ff;display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;font-stretch:normal;font-weight:700;-webkit-box-pack:center;-webkit-justify-content:center;-ms-flex-pack:center;justify-content:center;-webkit-letter-spacing:normal;-moz-letter-spacing:normal;-ms-letter-spacing:normal;letter-spacing:normal;line-height:1.54;outline:none;padding:11px 46px;-webkit-transition:-webkit-transform 0.2s;-webkit-transition:transform 0.2s;transition:transform 0.2s;font-size:16px;min-width:164px;max-width:284px;-webkit-text-decoration:none;text-decoration:none;margin-left:8px;} .hFWTst:not(:disabled):hover{-webkit-transform:scale(1.05);-ms-transform:scale(1.05);transform:scale(1.05);} .hFWTst:hover{color:#ffffff;cursor:pointer;} .hFWTst:disabled{background:#989898;cursor:not-allowed;} .hFWTst::after{-webkit-align-self:center;-ms-flex-item-align:center;align-self:center;content:'';display:none;height:15px;margin-left:10px;width:15px;} .hFWTst .LoadingIcon-sc-1naxssl-0{color:white;} @media screen and (max-width:1224px){} @media screen and (max-width:768px){.hFWTst{min-width:175px;margin-top:0px;}} @media screen and (max-width:680px){.hFWTst{max-width:100%;}} .hFWTst:not(:disabled).HeaderRateButton__StyledCompareProfessorButton-rxcxie-1:hover{background:#0021ff;-webkit-transform:none;-ms-transform:none;transform:none;} .hFWTst:not(:disabled).HeaderRateButton__StyledCompareProfessorButton-rxcxie-1:hover{background:#0021ff;-webkit-transform:none;-ms-transform:none;transform:none;} @media screen and (max-width:496px){.hFWTst{margin-left:0px;}}
# /* sc-component-id: HeaderRateButton__SchoolActionButtons-rxcxie-4 */
# .jorcU{display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-flex-direction:column;-ms-flex-direction:column;flex-direction:column;-webkit-align-items:flex-start;-webkit-box-align:flex-start;-ms-flex-align:flex-start;align-items:flex-start;gap:12px;min-width:100%;} @media screen and (max-width:1440px){.jorcU{-webkit-flex-direction:column;-ms-flex-direction:column;flex-direction:column;-webkit-align-items:flex-start;-webkit-box-align:flex-start;-ms-flex-align:flex-start;align-items:flex-start;}}
# /* sc-component-id: HeaderRateButton__StyledButtonWrapper-rxcxie-5 */
# .iICgQL{display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-flex-direction:row;-ms-flex-direction:row;flex-direction:row;margin-top:8px;} @media screen and (max-width:496px){.iICgQL{gap:8px;min-width:100%;}}
# /* sc-component-id: HeaderDescription__StyledInfoContainer-sc-1lt205f-0 */
# .deMmer{min-width:100%;} @media screen and (min-width:1225px){.deMmer{margin:0 auto;max-width:1224px;width:100%;}} @media screen and (max-width:768px){.deMmer{width:100%;}}
# /* sc-component-id: HeaderDescription__StyledTitleName-sc-1lt205f-1 */
# .egjGwd{-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-flex-direction:row;-ms-flex-direction:row;flex-direction:row;font-weight:bold;line-height:36px;padding-bottom:2px;text-align:left;font-family:Poppins,sans-serif;font-weight:900;} @media screen and (max-width:768px){.egjGwd{-webkit-box-pack:justify;-webkit-justify-content:space-between;-ms-flex-pack:justify;justify-content:space-between;}} .egjGwd .TeacherBookmark__StyledTeacherBookmark-sc-17dr6wh-0{margin-top:7px;} @media screen and (max-width:768px){.egjGwd .TeacherBookmark__StyledTeacherBookmark-sc-17dr6wh-0{margin-right:10px;margin-top:6px;}} .egjGwd .TeacherBookmark__StyledTeacherBookmark-sc-17dr6wh-0 img{width:30px;} .egjGwd .TeacherBookmark__StyledTeacherBookmark-sc-17dr6wh-0:hover{cursor:pointer;}
# /* sc-component-id: HeaderDescription__StyledCityState-sc-1lt205f-2 */
# .iaBBKY{color:#7E7E7E;display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;font-size:16px;font-weight:500;-webkit-box-pack:left;-webkit-justify-content:left;-ms-flex-pack:left;justify-content:left;line-height:20px;margin-bottom:4px;max-width:100%;}
# /* sc-component-id: HeaderDescription__StyledSubTitlesContainer-sc-1lt205f-4 */
# .dTNeOJ{font-size:16px;font-weight:700;line-height:20px;max-width:100%;text-align:left;} .dTNeOJ .span{color:#7E7E7E;}
# /* sc-component-id: HeaderDescription__NameWrapper-sc-1lt205f-5 */
# .fSkQCp{font-size:32px;-webkit-text-decoration:none;text-decoration:none;white-space:normal;font-family:Poppins,sans-serif;font-weight:900;} @media screen and (max-width:768px){.fSkQCp{font-size:28px;line-height:28px;}}
# /* sc-component-id: HeaderDescription__StyledInfo-sc-1lt205f-7 */
# .eKGsjy{-webkit-align-content:center;-ms-flex-line-pack:center;align-content:center;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;-webkit-box-pack:start;-webkit-justify-content:flex-start;-ms-flex-pack:start;justify-content:flex-start;max-width:732px;}
# /* sc-component-id: StickyHeaderContent__StyledLeftColumn-sc-1cjn6w2-0 */
# .iYFgni{font-size:54px;width:100%;text-align:left;}
# /* sc-component-id: StickyHeaderContent__StyledRightColumn-sc-1cjn6w2-1 */
# .kQGiGx{width:100%;text-align:right;} @media screen and (max-width:1280px){.kQGiGx{display:none;}}
# /* sc-component-id: StickyHeader__StyledStickyHeader-sc-19g16mb-0 */
# .dpCfpS{background:white;box-shadow:0px 4px 4px rgba(126,126,126,0.25);display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;height:100%;min-width:100%;position:absolute;top:62px;z-index:60000;opacity:0;-webkit-transform:translateY(-20px);-ms-transform:translateY(-20px);transform:translateY(-20px);pointer-events:none;-webkit-transition:opacity 0.5s ease,-webkit-transform 0.5s ease;-webkit-transition:opacity 0.5s ease,transform 0.5s ease;transition:opacity 0.5s ease,transform 0.5s ease;} @media screen and (max-width:1440px){} @media screen and (max-width:768px){.dpCfpS{min-height:172px;}}
# /* sc-component-id: StickyHeader__StyledInnerContainer-sc-19g16mb-1 */
# .gDtLGS{display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-flex-direction:row;-ms-flex-direction:row;flex-direction:row;-webkit-box-pack:justify;-webkit-justify-content:space-between;-ms-flex-pack:justify;justify-content:space-between;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;padding-top:8px;padding-bottom:16px;} @media screen and (min-width:1225px){.gDtLGS{margin:0 auto;max-width:1224px;width:100%;}} @media screen and (max-width:1280px){.gDtLGS{padding-right:20px;padding-left:24px;}} @media screen and (max-width:768px){.gDtLGS{min-width:100%;}}
# /* sc-component-id: TeacherRatingsPage__RatingColumn-sc-1gyr13u-0 */
# .kezNwl{display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-flex:1 0 50%;-ms-flex:1 0 50%;flex:1 0 50%;-webkit-flex-flow:column nowrap;-ms-flex-flow:column nowrap;flex-flow:column nowrap;padding-right:22px;}
# /* sc-component-id: TeacherRatingsPage__TeacherBlock-sc-1gyr13u-1 */
# .flKehn{display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-flex-flow:row;-ms-flex-flow:row;flex-flow:row;-webkit-box-pack:justify;-webkit-justify-content:space-between;-ms-flex-pack:justify;justify-content:space-between;margin-bottom:6px;padding-left:22px;} @media screen and (max-width:1224px){.flKehn{-webkit-flex-flow:column;-ms-flex-flow:column;flex-flow:column;margin-bottom:16px;}} @media screen and (max-width:984px){.flKehn{margin-bottom:24px;}} @media screen and (min-width:1225px){.flKehn{max-width:calc(1224px - 354px);}}
# /* sc-component-id: TeacherRatingsPage__StyledAdLeaderboardWrapper-sc-1gyr13u-2 */
# .fVZsFn{padding-left:24px !important;}
# /* sc-component-id: TeacherRatingsPage__StyledJWVideoPlayerContainer-sc-1gyr13u-3 */
# .htLcUt{margin-top:16px;max-width:564px;}
# /* sc-component-id: Search__SearchInputContainer-sc-10lefvq-0 */
# .koGnqT{position:relative;}
# /* sc-component-id: NewSearch__StyledSearchWrapper-pkxwmu-0 */
# .eJRnwy{position:relative;width:100%;} .eJRnwy .SearchTypeahead__StyledSearchTypeaheadDropdown-sc-1i57108-0{box-shadow:0px 4px 4px rgba(151,151,151,0.3);top:50px;} .eJRnwy .Search__SearchInputContainer-sc-10lefvq-0{max-width:545px;width:100%;}
# /* sc-component-id: NewSearch__StyledSearch-pkxwmu-1 */
# .ksrzOn .Search__DebouncedSearchInput-sc-10lefvq-1{border:0;border-radius:43px;color:#9e9e9e;font-size:20px;max-width:545px;outline:none;width:100%;} .ksrzOn .Search__DebouncedSearchInput-sc-10lefvq-1::-webkit-input-placeholder{color:#9e9e9e;} .ksrzOn .Search__DebouncedSearchInput-sc-10lefvq-1::-moz-placeholder{color:#9e9e9e;} .ksrzOn .Search__DebouncedSearchInput-sc-10lefvq-1:-ms-input-placeholder{color:#9e9e9e;} .ksrzOn .Search__DebouncedSearchInput-sc-10lefvq-1::placeholder{color:#9e9e9e;} .ksrzOn .Search__DebouncedSearchInput-sc-10lefvq-1 .SearchTypeahead__StyledSearchTypeaheadDropdown-sc-1i57108-0{max-width:545px;width:100%;}
# /* sc-component-id: NewSearch__SearchIconWrapper-pkxwmu-2 */
# .irUZwm{left:27px;position:absolute;top:17px;width:-webkit-fit-content;width:-moz-fit-content;width:fit-content;z-index:2;}
# /* sc-component-id: SearchContainer__StyledNewSearch-crnhs3-0 */
# .hxCzZQ .Search__DebouncedSearchInput-sc-10lefvq-1{border:0;}
# /* sc-component-id: ModalButtonLink__StyledButton-sc-1soj3zs-0 */
# .khahiz{background:none;border:0;font-size:inherit;margin:0;outline:none;padding:0;} .khahiz:hover{cursor:pointer;}
# /* sc-component-id: TeacherSchoolToggleButton__StyledToggleButton-sc-15dbb0q-0 */
# .gmfVsA{-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;background:none;border:0;color:white;cursor:pointer;display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;margin-right:14px;outline:none;position:relative;} @media screen and (max-width:768px){.gmfVsA{display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;margin-right:0;}} .gmfVsA svg{margin-right:5px;} @media screen and (max-width:768px){.gmfVsA svg{margin-right:11px;}}
# /* sc-component-id: TeacherSchoolToggleButton__ToggleButtonText-sc-15dbb0q-2 */
# .itGGhm{color:white;font-size:18px;line-height:21px;padding-right:10px;} @media screen and (max-width:768px){.itGGhm{display:none;}}
# /* sc-component-id: TeacherSchoolToggleButton__IconWrapper-sc-15dbb0q-4 */
# @media screen and (max-width:1024px){.kljOpt{display:none;}} @media screen and (max-width:768px){.kljOpt{display:block;}}
# /* sc-component-id: UserMenu__LoginLink-sc-1rv45rg-0 */
# .ftqFWl{background:transparent;color:white;display:block;font-weight:700;height:100%;-webkit-text-decoration:none;text-decoration:none;border-radius:20px;cursor:pointer;margin-left:16px;padding:8px 16px;white-space:nowrap;} .ftqFWl:hover{background:#313131;} .ftqFWl:last-of-type{border:1px solid white;margin:0;} .ftqFWl:last-of-type:hover{border:1px solid transparent;} .ftqFWl:last-of-type{margin-left:16px;}
# /* sc-component-id: UserMenu__SignUpLink-sc-1rv45rg-1 */
# .bLuxdV{color:white;display:block;font-weight:700;height:100%;-webkit-text-decoration:none;text-decoration:none;border-radius:20px;cursor:pointer;margin-left:16px;padding:8px 16px;white-space:nowrap;} .bLuxdV:hover{background:#313131;} .bLuxdV:last-of-type{border:1px solid white;margin:0;} .bLuxdV:last-of-type:hover{border:1px solid transparent;}
# /* sc-component-id: UserMenu__UserMenuWrapper-sc-1rv45rg-2 */
# .fsOMKN{display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;}
# /* sc-component-id: HelpScout__HelpScoutButtonLink-sc-16p8tnd-0 */
# .gYUKbL{color:white;display:block;font-weight:700;height:100%;-webkit-text-decoration:none;text-decoration:none;border-radius:20px;cursor:pointer;margin-left:16px;padding:8px 16px;white-space:nowrap;background-color:white;color:black;min-width:72px;} .gYUKbL:hover{background:#313131;} .gYUKbL:last-of-type{border:1px solid white;margin:0;} .gYUKbL:last-of-type:hover{border:1px solid transparent;} @media screen and (max-width:1024px){.gYUKbL{display:none;}}
# /* sc-component-id: sc-global-669748234 */
# @font-face{font-family:'Poppins';font-style:normal;font-weight:400;src:url('/fonts/poppins-v8-latin-regular.eot');src:local('Poppins Regular'),local('Poppins-Regular'),url('/fonts/poppins-v8-latin-regular.eot?#iefix') format('embedded-opentype'),url('/fonts/poppins-v8-latin-regular.woff2') format('woff2'),url('/fonts/poppins-v8-latin-regular.woff') format('woff'),url('/fonts/poppins-v8-latin-regular.ttf') format('truetype'),url('/fonts/poppins-v8-latin-regular.svg#Poppins') format('svg');} @font-face{font-family:'Poppins';font-style:italic;font-weight:400;src:url('/fonts/poppins-v8-latin-italic.eot');src:local('Poppins Italic'),local('Poppins-Italic'),url('/fonts/poppins-v8-latin-italic.eot?#iefix') format('embedded-opentype'),url('/fonts/poppins-v8-latin-italic.woff2') format('woff2'),url('/fonts/poppins-v8-latin-italic.woff') format('woff'),url('/fonts/poppins-v8-latin-italic.ttf') format('truetype'),url('/fonts/poppins-v8-latin-italic.svg#Poppins') format('svg');} @font-face{font-family:'Poppins';font-style:normal;font-weight:700;src:url('/fonts/poppins-v8-latin-700.eot');src:local('Poppins Bold'),local('Poppins-Bold'),url('/fonts/poppins-v8-latin-700.eot?#iefix') format('embedded-opentype'),url('/fonts/poppins-v8-latin-700.woff2') format('woff2'),url('/fonts/poppins-v8-latin-700.woff') format('woff'),url('/fonts/poppins-v8-latin-700.ttf') format('truetype'),url('/fonts/poppins-v8-latin-700.svg#Poppins') format('svg');} @font-face{font-family:'Poppins';font-style:italic;font-weight:700;src:url('/fonts/poppins-v8-latin-700italic.eot');src:local('Poppins Bold Italic'),local('Poppins-BoldItalic'),url('/fonts/poppins-v8-latin-700italic.eot?#iefix') format('embedded-opentype'),url('/fonts/poppins-v8-latin-700italic.woff2') format('woff2'),url('/fonts/poppins-v8-latin-700italic.woff') format('woff'),url('/fonts/poppins-v8-latin-700italic.ttf') format('truetype'),url('/fonts/poppins-v8-latin-700italic.svg#Poppins') format('svg');} @font-face{font-family:'Poppins';font-style:normal;font-weight:900;src:url('/fonts/poppins-v8-latin-900.eot');src:local('Poppins Black'),local('Poppins-Black'),url('/fonts/poppins-v8-latin-900.eot?#iefix') format('embedded-opentype'),url('/fonts/poppins-v8-latin-900.woff2') format('woff2'),url('/fonts/poppins-v8-latin-900.woff') format('woff'),url('/fonts/poppins-v8-latin-900.ttf') format('truetype'),url('/fonts/poppins-v8-latin-900.svg#Poppins') format('svg');} @font-face{font-family:'Poppins';font-style:italic;font-weight:900;src:url('/fonts/poppins-v8-latin-900italic.eot');src:local('Poppins Black Italic'),local('Poppins-BlackItalic'),url('/fonts/poppins-v8-latin-900italic.eot?#iefix') format('embedded-opentype'),url('/fonts/poppins-v8-latin-900italic.woff2') format('woff2'),url('/fonts/poppins-v8-latin-900italic.woff') format('woff'),url('/fonts/poppins-v8-latin-900italic.ttf') format('truetype'),url('/fonts/poppins-v8-latin-900italic.svg#Poppins') format('svg');} html,body,div,span,applet,object,iframe,h1,h2,h3,h4,h5,h6,p,blockquote,pre,a,abbr,acronym,address,big,cite,code,del,dfn,em,img,ins,kbd,q,s,samp,small,strike,strong,sub,sup,tt,var,b,u,i,center,dl,dt,dd,ol,ul,li,fieldset,form,label,legend,table,caption,tbody,tfoot,thead,tr,th,td,article,aside,canvas,details,embed,figure,figcaption,footer,header,hgroup,main,menu,nav,output,ruby,section,summary,time,mark,audio,video{margin:0;padding:0;border:0;font-size:100%;font:inherit;vertical-align:baseline;} article,aside,details,figcaption,figure,footer,header,hgroup,main,menu,nav,section{display:block;} *[hidden]{display:none;} body{line-height:1;} ol,ul{list-style:none;} blockquote,q{quotes:none;} blockquote:before,blockquote:after,q:before,q:after{content:'';content:none;} table{border-collapse:collapse;border-spacing:0;} #beacon-container .BeaconFabButtonFrame{display:none;} #beacon-container .BeaconContainer{bottom:24px;right:15px;z-index:2147483637 !important;} body,div,a,button{color:#151515;font-family:HelveticaNeue,arial;font-size:14px;} b{font-w ...
# /* sc-component-id: SocialIconLink__SocialIcon-sc-1iq78in-0 */
# .jJWSqG{box-sizing:content-box;height:18px;padding-left:20px;width:18px;} @media screen and (max-width:768px){.jJWSqG{padding:0px 10px;}}
# /* sc-component-id: SocialIconLink__StyledSocialIconLink-sc-1iq78in-1 */
# .WZsQZ:first-child .SocialIconLink__SocialIcon-sc-1iq78in-0{padding-left:0px;}
# /* sc-component-id: SocialLinks__StyledSocialLinks-bn65ay-0 */
# .fxTUTO{display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;margin-bottom:16px;position:relative;} @media (min-width:768px){.fxTUTO{display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-box-pack:center;-webkit-justify-content:center;-ms-flex-pack:center;justify-content:center;}}
# /* sc-component-id: ToastContainer__StyledToastContainer-sc-1csk9fr-0 */
# .hsMvnW .toast{margin-bottom:0.25rem;}
# /* sc-component-id: MobileMenu__MobileMenuWrapper-mf2apz-0 */
# .ecMUyP{display:none;}
# /* sc-component-id: MobileMenu__MenuButton-mf2apz-2 */
# .cdrVhb{background:none;background-image:url(/static/media/hamburger-icon-light.e395d28a.svg);background-repeat:no-repeat;background-size:contain;border:0;-webkit-flex:0 0 auto;-ms-flex:0 0 auto;flex:0 0 auto;height:14px;margin:8px;outline:none;width:19px;}
# ...
#           data-website-id="3905"
#           charset="utf-8"
#         ></script>
#
#         <!-- Blockthrough -->
#         <script type="text/javascript" async src="https://btloader.com/tag?o=5769520222306304&upapi=true"></script>
#
#         <!-- Outbrain -->
#         <script type="text/javascript" async src="https://widgets.outbrain.com/outbrain.js"></script>
#
#       </head>
#       <body >
#         <!-- Google Tag Manager (noscript) -->
#         <noscript><iframe src="https://www.googletagmanager.com/ns.html?id=GTM-5HVQ56V" height="0" width="0" style="display:none;visibility:hidden"></iframe></noscript>
#         <!-- End Google Tag Manager (noscript) -->
#
#         <div id="root"><div class="App__StyledApp-aq7j9t-0 kaBGnN"><div class="App__Body-aq7j9t-1 bhyGpW"><div data-testid="StyledHeaderContainer" class="HeaderContainer__StyledHeaderContainer-sc-1eya4wu-0 ducGvC"><div class="Header__HeaderBannerWrapper-sc-1oduwjk-5 enzK"><header role="banner" class="Header__StyledHeader-sc-1oduwjk-1 hNQJBj"><div class="Toastify"></div><div class="Header__HeaderWrapper-sc-1oduwjk-4 fWcpms"><div class="Header__StyledDummyElement-sc-1oduwjk-3 kjTgMJ"></div><div class="HeaderLogo__StyledHeaderLogo-sc-1ehuz2f-2 vWase"><div class="MobileMenu__MobileMenuWrapper-mf2apz-0 ecMUyP"><button title="Mobile Menu Button" class="MobileMenu__MenuButton-mf2apz-2 cdrVhb"></button></div><a href="/"><img src="/static/media/small_rmp_logo_white.4d5ff7fa.svg" alt="Logo" class="HeaderLogo__RMPLogo-sc-1ehuz2f-1 bFAPID"/></a><button type="button" title="Open search menu" class="HeaderLogo__SearchIcon-sc-1ehuz2f-0 bFqXne"><img src="/static/media/search-white.7b02d8be.svg" alt="Search Icon"/></button></div><div class="HeaderSearch__StyledNewSearch-zmx6ds-0 fiaAxo"><div class="HeaderSearchMainInput__MainInputWrapper-nft009-0 jBOPiI"><div><button type="button" role="button" title="Header Type Toggle Button" class="TeacherSchoolToggleButton__StyledToggleButton-sc-15dbb0q-0 gmfVsA"><span class="TeacherSchoolToggleButton__IconWrapper-sc-15dbb0q-4 kljOpt"> <svg width="18" height="21" viewBox="0 0 18 21" fill="none" xmlns="http://www.w3.org/2000/svg"><path fill-rule="evenodd" clip-rule="evenodd" d="
age__StyledAdLeaderboardWrapper-sc-1gyr13u-2 fVZsFn"><div id="ad-header-leaderboard" role="complementary" alt="advertisement leaderboard" aria-label="advertisement leaderboard" class="AdLeaderboard__StyledAdLeaderboard-sc-1gj31a6-0 gtQHFe"><div class="AdLeaderboard__AdWrapper-sc-1gj31a6-1 frDnMc"><div id="ad-container-wunderkind" class="AdLeaderboard__StyledWunderkindWrapper-sc-1gj31a6-2 EJltd"></div></div></div></div><div class="TeacherRatingsPage__TeacherBlock-sc-1gyr13u-1 flKehn"><div class="TeacherInfo__StyledTeacher-ti1fio-1 kFNvIp"><div><div class="RatingValue__AvgRating-qw8sqy-1 gIgExh"><div class="RatingValue__AvgRatingWrapper-qw8sqy-3 bIUJtl"><div class="RatingValue__Numerator-qw8sqy-2 liyUjw">1.1</div><div class="RatingValue__Denominator-qw8sqy-4 UqFtE">/ 5</div></div><a class="JumpToRatings__StyledJumpToRatings-sc-1v42jg0-0 eTpHeJ" href="/professor/2936075#ratingsList"><span>Jump To Ratings</span> <img src="/static/media/down-arrow-black.531d82ab.svg" alt="Down Arrow"/></a></div><div class="RatingValue__NumRatings-qw8sqy-0 jMkisx"><div>Overall Quality Based on <a href="#ratingsList">108<!-- --> ratings</a></div></div></div><div><div class="NameTitle__Name-dowf0z-0 cfjPUG"><h1 class="NameTitle__NameWrapper-dowf0z-2 erLzyk">Mark<!-- --> <!-- -->Wilson<button class="TeacherBookmark__StyledTeacherBookmark-sc-17dr6wh-0 hVjzhH" type="button"><img src="/static/media/bookmark-default.b056b070.svg" alt="Bookmark" data-tooltip="true" data-tip="Save Professor" data-for="GLOBAL_TOOLTIP"/></button></h1></div><div class="NameTitle__Title-dowf0z-1 iLYGwn"><span>Professor in the<!-- --> <a class="TeacherDepartment__StyledDepartmentLink-fl79e8-0 iMmVHb" href="/search/professors/1513?q=*&amp;did=11"><b>Computer Science<!-- --> department</b></a> <!-- -->at<!-- --> </span><a href="/school/1513">University of M ...
#         <script>
#           window.__RELAY_STORE__ = {"client:root":{"__id":"client:root","__typename":"__Root","node(id:\"VGVhY2hlci0yOTM2MDc1\")":{"__ref":"VGVhY2hlci0yOTM2MDc1"}},"VGVhY2hlci0yOTM2MDc1":{"__id":"VGVhY2hlci0yOTM2MDc1","__typename":"Teacher","id":"VGVhY2hlci0yOTM2MDc1","legacyId":2936075,"firstName":"Mark","lastName":"Wilson","department":"Computer Science","school":{"__ref":"U2Nob29sLTE1MTM="},"lockStatus":"none","isSaved":false,"numRatings":108,"ratingsDistribution":{"__ref":"client:VGVhY2hlci0yOTM2MDc1:ratingsDistribution"},"avgRating":1.1,"departmentId":"11","teacherRatingTags":{"__refs":["VGVhY2hlclJhdGluZ1RhZ3MtMQ==","VGVhY2hlclJhdGluZ1RhZ3MtMg==","VGVhY2hlclJhdGluZ1RhZ3MtMw==","VGVhY2hlclJhdGluZ1RhZ3MtNQ==","VGVhY2hlclJhdGluZ1RhZ3MtOA==","VGVhY2hlclJhdGluZ1RhZ3MtOQ==","
{"__id":"VGVhY2hlclJhdGluZ1RhZ3MtOQ==","__typename":"TeacherRatingTags","legacyId":9,"tagCount":1,"tagName":"Clear grading criteria","id":"VGVhY2hlclJhdGluZ1RhZ3MtOQ=="},"VGVhY2hlclJhdGluZ1RhZ3MtMTI=":{"__id":"VGVhY2hlclJhdGluZ1RhZ3MtMTI=","__typename":"TeacherRatingTags","legacyId":12,"tagCount":1,"tagName":"Gives good feedback","id":"VGVhY2hlclJhdGluZ1RhZ3MtMTI="},"VGVhY2hlclJhdGluZ1RhZ3MtMTM=":{"__id":"VGVhY2hlclJhdGluZ1RhZ3MtMTM=","__typename":"TeacherRatingTags","legacyId":13,"tagCount":4,"tagName":"Inspirational","id":"VGVhY2hlclJhdGluZ1RhZ3MtMTM="},"VGVhY2hlclJhdGluZ1RhZ3MtMTQ=":{"__id":"VGVhY2hlclJhdGluZ1RhZ3MtMTQ=","__typename":"TeacherRatingTags","legacyId":14,"tagCount":32,"tagName":"Lots of homework","id":"VGVhY2hlclJhdGluZ1RhZ3MtMTQ="},"VGVhY2hlclJhdGluZ1RhZ3MtMTU=":{"__id":"VGVhY2hlclJhdGluZ1RhZ3MtMTU=","__typename":"TeacherRat ...
#           window.process = {}
#           window.process.env = {"REACT_APP_GTM_KEY":"GTM-5HVQ56V","REACT_APP_USE_OAUTH":"true","REACT_APP_NODE_NAME":"ip-10-10-84-0.ec2.internal","REACT_APP_NEW_FORMS":"false","REACT_APP_GA_PROPERTY":"UA-130629720-1","REACT_APP_USE_SITE_TAKEOVER":"false","REACT_APP_USE_COMPARE_PROFESSORS":"true","REACT_APP_MAINTENANCE_MODE":"false","REACT_APP_POD_NAME":"lockhart-776547f7dc-ghvfh","REACT_APP_NAMESPACE":"rmp","REACT_APP_SENTRY_DSN":"https://4ed46c377b9079fac60345be9a767a5e@o4506933484716032.ingest.us.sentry.io/4507023893069824","REACT_APP_GRAPHQL_AUTH":"dGVzdDp0ZXN0","REACT_APP_SHOW_MCGRAWHILL":"false","REACT_APP_AD_BUNDLE_URL":"https://public.servenobid.com/partner/66897/56514/wrapup_1.0.2.js","REACT_APP_ENV":"production","REACT_APP_HERMIONE_URL":"","REACT_APP_RECAPTCHA_V3_KEY":"6LdkVtEZAAAAAKhKVS339ciry1dTTSH1hLOFAeN6","REACT_APP_USE_COMPARE_SCHOOLS":"true","REACT_APP_HOTJAR_KEY":"1667000","REACT_APP_SHOW_CENGAGE":"false"};
#         </script>
#         <script src="/static/js/main.1b811119.js"></script>
#       </body>
#     </html>

# %%
import json
import re
import pandas as pd

def extract_reviews_from_html(html_content):
    # Find the JavaScript data object that contains the reviews
    data_match = re.search(r'window\.__RELAY_STORE__ = ({.*?});', html_content, re.DOTALL)
    if not data_match:
        print("No data found in HTML")
        return []
    
    try:
        # Parse the JavaScript object
        data = json.loads(data_match.group(1))
        
        reviews = []
        # Look for rating objects in the data
        # Print all possible keys from the first rating found
        for key, value in data.items():
            if isinstance(value, dict) and value.get('__typename') == 'Rating':
                print("All keys in first rating:")
                for k in value.keys():
                    print(f"- {k}")
                
                review = {
                    'comment': value.get('comment'),
                    'date': value.get('date'), 
                    'class': value.get('class'),
                    'grade': value.get('grade'),
                    'difficulty': value.get('difficultyRating'),
                    'quality': value.get('helpfulRating'),
                    'tags': value.get('ratingTags'),
                    'would_take_again': value.get('wouldTakeAgain')
                }
                reviews.append(review)
                break  # Only need to print keys from first rating
                
        # Continue collecting all reviews
        for key, value in data.items():
            if isinstance(value, dict) and value.get('__typename') == 'Rating':
                review = {
                    'comment': value.get('comment'),
                    'date': value.get('date'),
                    'class': value.get('class'),
                    'grade': value.get('grade'),
                    'difficulty': value.get('difficultyRating'),
                    'quality': value.get('helpfulRating'),
                    'tags': value.get('ratingTags'),
                    'would_take_again': value.get('wouldTakeAgain')
                }
                reviews.append(review)
        
        return reviews
        
    except json.JSONDecodeError as e:
        print(f"Error parsing JSON data: {e}")
        return []

# Get reviews from your HTML content
reviews = extract_reviews_from_html(r.text)

# Convert to DataFrame
df = pd.DataFrame(reviews)

# Basic cleaning
df['date'] = pd.to_datetime(df['date'].str.split(' ').str[0])
df = df.sort_values('date', ascending=False)

# Save to CSV
#df.to_csv('professor_reviews.csv', index=False)

# Print summary
print(f"Extracted {len(reviews)} reviews")
print("\nMost recent reviews:")
print(df[['date', 'class', 'difficulty', 'quality']].head())
# Out:
# All keys in first rating:
# - __id
# - __typename
# - comment
# - flagStatus
# - createdByUser
# - teacherNote
# - legacyId
# - date
# - class
# - helpfulRating
# - clarityRating
# - isForOnlineClass
# - difficultyRating
# - attendanceMandatory
# - wouldTakeAgain
# - grade
# - textbookUse
# - isForCredit
# - ratingTags
# - id
# - adminReviewedAt
# - thumbsUpTotal
# - thumbsDownTotal
# - thumbs
# Extracted 21 reviews
#
# Most recent reviews:
#         date       class  difficulty  quality
# 0 2025-01-15       CS575           5        1
# 1 2025-01-15       CS575           5        1
# 2 2024-12-21       CS575           5        1
# 3 2024-12-11       CS575           5        1
# 4 2024-11-18  COMPSCI240           5        1

# %%
import requests
import json
import pandas as pd
import time

import base64

def get_all_reviews(professor_id):
    headers = {
        'Authorization': 'Basic dGVzdDp0ZXN0',
        'Content-Type': 'application/json',
        'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/91.0.4472.124 Safari/537.36'
    }
    
    # Encode the professor_id in base64
    encoded_professor_id = base64.b64encode(f"Teacher-{professor_id}".encode()).decode()
    
    payload = {
        "query": "query GetTeacherRatings($id: ID!) { node(id: $id) { ... on Teacher { id firstName lastName school { name } ratings(first: 1000) { edges { node { comment class difficultyRating qualityRating createdByUser attendanceMandatory wouldTakeAgain isForCredit textbookUse date } } pageInfo { hasNextPage endCursor } } } } }",
        "variables": {
            "id": encoded_professor_id
        }
    }
    
    response = requests.post(
        "https://www.ratemyprofessors.com/graphql",
        json=payload,
        headers=headers
    )
    
    if response.status_code != 200:
        print(f"Error: Status code {response.status_code}")
        print(response.text)
        return None
        
    data = response.json()
    
    # Check for errors in the response
    if 'errors' in data:
        print("GraphQL Errors:", data['errors'])
        return None
        
    node_list = data['data']['node']['ratings']['edges']

    rev_list = []
    for node in node_list:
        node['node']['tid'] = professor_id
        rev_list.append(node['node'])
    return rev_list

# Test the function
professor_id = "2936075"  # Mark Wilson's ID
result = get_all_reviews(professor_id)
print(json.dumps(result, indent=2))
# Out:
# [
#   {
#     "attendanceMandatory": "",
#     "class": "CS575",
#     "comment": "Didn't offer a make-up exam for the midterm, which made the final exam 50% of my grade. The final exam was extremely hard, he didn't offer any regrade requests for the final, and closed the Piazza almost immediately after the final so we couldn't dispute anything. Allowing him to teach a CS course again was a huge mistake for the CS department.",
#     "createdByUser": false,
#     "date": "2025-01-15 21:34:45 +0000 UTC",
#     "difficultyRating": 5,
#     "isForCredit": true,
#     "qualityRating": 1,
#     "textbookUse": null,
#     "wouldTakeAgain": null,
#     "tid": "2936075"
#   },
#   {
#     "attendanceMandatory": "mandatory",
#     "class": "CS575",
#     "comment": "If you can avoid him, please do. As said before, he is extremely condescending and lacking in patience when answering questions. He will call a new examinable concept simple or powerful or both, then not explain it. He will be unable to finish examples he's supposed to be teaching the class. Exams are nothing like the lectures or coursework.",
#     "createdByUser": false,
#     "date": "2024-12-21 02:15:43 +0000 UTC",
#     "difficultyRating": 5,
#     "isForCredit": true,
#     "qualityRating": 1,
#     "textbookUse": -1,
#     "wouldTakeAgain": null,
#     "tid": "2936075"
#   },
#   {
#     "attendanceMandatory": "mandatory",
#     "class": "CS575",
#     "comment": "Mark Wilson's problem is that he doesn't explain the most basic steps and assumptions, and often skips straight to harder material which can lead to confusion. He would often try to prove something without preparation, state something was obvious, then fail to complete it. Everyone failed the midterm and he blamed it on us.",
#     "createdByUser": false,
#     "date": "2024-12-11 00:10:36 +0000 UTC",
#     "difficultyRating": 5,
#     "isForCredit": true,
#     "qualityRating": 1,
#     "textbookUse": -1,
#     "wouldTakeAgain": null,
#     "tid": "2936075"
#   },
#   {
#     "attendanceMandatory": "non mandatory",
#     "class": "COMPSCI240",
#     "comment": "Brags about how many students fail his exams. Inflexible regarding personal issues and won't listen if you have interviews to attend. Refuses to give intuition or practical examples so if you're not strong in stats you'll struggle. The only good part is that Spring 2025 is going to be Wilson's last semester teaching at UMass.",
#     "createdByUser": false,
#     "date": "2024-11-18 14:18:29 +0000 UTC",
#     "difficultyRating": 5,
#     "isForCredit": true,
#     "qualityRating": 1,
#     "textbookUse": -1,
#     "wouldTakeAgain": null,
#     "tid": "2936075"
#   },
#   {
#     "attendanceMandatory": "non mandatory",
#     "class": "CS240",
#     "comment": "If you're lucky enough to avoid 240 or any class with Wilson, please do! He's straight up immature and won't admit when he's wrong. Marius makes classes like 220 enjoyably hard and good learning experiences. Wilson, on the other hand, will make 240 artificially hard and it will just be a frustrating experience with unrewarding, \"robotic\" lectures.",
#     "createdByUser": false,
#     "date": "2024-11-18 14:11:57 +0000 UTC",
#     "difficultyRating": 5,
#     "isForCredit": true,
#     "qualityRating": 1,
#     "textbookUse": -1,
#     "wouldTakeAgain": null,
#     "tid": "2936075"
#   },
#   {
#     "attendanceMandatory": "",
#     "class": "CS240",
#     "comment": "If you really want to learn something, don't take 240 or ANY class with Wilson.",
#     "createdByUser": false,
#     "date": "2024-11-17 19:19:48 +0000 UTC",
#     "difficultyRating": 5,
#     "isForCredit": true,
#     "qualityRating": 1,
#     "textbookUse": -1,
#     "wouldTakeAgain": null,
#     "tid": "2936075"
#   },
#   {
#     "attendanceMandatory": "mandatory",
#     "class": "CS575",
#     "comment": "Wilson has an unwarranted superiority complex that is quite proven in the way he takes pleasure in not caring about student success, learning, or mental health; his attitude is most definitely akin to that of the stereotypical IT body shop manager who doesn't believe in a healthy work-life balance but rather delights in condescending behavior.",
#     "createdByUser": false,
#     "date": "2024-11-12 17:03:11 +0000 UTC",
#     "difficultyRating": 5,
#     "isForCredit": true,
#     "qualityRating": 1,
#     "textbookUse": null,
#     "wouldTakeAgain": null,
#     "tid": "2936075"
#   },
#   {
#     "attendanceMandatory": "non mandatory",
#     "class": "CS240",
#     "comment": "Most unpleasant guy I have ever had the misfortune to meet. Lectures were always unrewarding and made no sense. 240 isn't supposed to be hard but Wilson will find a way to make that happen, and it will just be a frustrating experience. He really doesn't want students to do well, and extra help is nowhere. If you have the option to avoid him do it!",
#     "createdByUser": false,
#     "date": "2024-11-12 16:54:29 +0000 UTC",
#     "difficultyRating": 5,
#     "isForCredit": true,
#     "qualityRating": 1,
#     "textbookUse": -1,
#     "wouldTakeAgain": null,
#     "tid": "2936075"
#   },
#   {
#     "attendanceMandatory": "mandatory",
#     "class": "COMPSCI240",
#     "comment": "if your idea of a fun class involves existential dread and perpetual frustration, then wilson's class is the perfect fit for you!",
#     "createdByUser": false,
#     "date": "2024-11-01 21:07:47 +0000 UTC",
#     "difficultyRating": 5,
#     "isForCredit": true,
#     "qualityRating": 1,
#     "textbookUse": -1,
#     "wouldTakeAgain": null,
#     "tid": "2936075"
#   },
#   {
#     "attendanceMandatory": "non mandatory",
#     "class": "CS240",
#     "comment": "Wilson doesn't just teach CS240; he orchestrates a symphony of suffering. Each homework assignment is a torturous opus, and exams are the grand finale where your sanity takes center stage. Enroll if you enjoy being academically maimed.",
#     "createdByUser": false,
#     "date": "2024-11-01 21:06:45 +0000 UTC",
#     "difficultyRating": 5,
#     "isForCredit": true,
#     "qualityRating": 1,
#     "textbookUse": -1,
#     "wouldTakeAgain": null,
#     "tid": "2936075"
#   },
#   {
#     "attendanceMandatory": "non mandatory",
#     "class": "CS240",
#     "comment": "It cost me my sleep plus all my sacrifices to the devil just to score above a 70 on the first midterm. 240 with Wilson shaved a decade off my already short life. I wish I was joking. The CS department should've done a background check for Wilson because it's obvious his whole background is dirty as a result of delighting in viciousness and cruelty.",
#     "createdByUser": false,
#     "date": "2024-08-25 22:09:28 +0000 UTC",
#     "difficultyRating": 5,
#     "isForCredit": true,
#     "qualityRating": 1,
#     "textbookUse": -1,
#     "wouldTakeAgain": null,
#     "tid": "2936075"
#   },
#   {
#     "attendanceMandatory": "non mandatory",
#     "class": "CS240",
#     "comment": "Exceedingly harsh grader with unclear expectations. Makes it impossible to do well in this class. I've always gotten great scores on homeworks in every other class but struggled to get an A on any homework in this class. Really frustrating when your GPA is important to work at NVIDIA, MathWorks, or other top companies. Overall not a fun experience.",
#     "createdByUser": false,
#     "date": "2024-08-24 17:00:39 +0000 UTC",
#     "difficultyRating": 5,
#     "isForCredit": true,
#     "qualityRating": 1,
#     "textbookUse": -1,
#     "wouldTakeAgain": null,
#     "tid": "2936075"
#   },
#   {
#     "attendanceMandatory": "non mandatory",
#     "class": "COMPSCI240",
#     "comment": "His lectures are basically him saying \"This should be obvious\" while teaching students concepts instead of carefully taking time to offer thorough explanations. HWs are long. Exams are unreasonable to the point where you can't finish on time. Wilson is an obstructionist person. If you succeeded at CS240, it will be despite him, not because of him.",
#     "createdByUser": false,
#     "date": "2024-06-08 14:31:15 +0000 UTC",
#     "difficultyRating": 5,
#     "isForCredit": true,
#     "qualityRating": 1,
#     "textbookUse": -1,
#     "wouldTakeAgain": null,
#     "tid": "2936075"
#   },
#   {
#     "attendanceMandatory": "non mandatory",
#     "class": "CS240",
#     "comment": "I came into Wilson 240 with an open mind, but I clearly understand why Wilson has the low ratings he has. He rushes through lectures, his exams are trying to mentally break you, his homework policy sucks, and he is condescending and hostile to students who ask questions. This is a professor who truly doesn't care about student learning.",
#     "createdByUser": false,
#     "date": "2024-06-01 23:44:13 +0000 UTC",
#     "difficultyRating": 5,
#     "isForCredit": true,
#     "qualityRating": 1,
#     "textbookUse": -1,
#     "wouldTakeAgain": null,
#     "tid": "2936075"
#   },
#   {
#     "attendanceMandatory": "non mandatory",
#     "class": "CS240",
#     "comment": "If you're lucky enough to avoid Wilson for CS240, do it! Rude, disrespectful to honest student concerns, refuses to offer intuition behind hard topics, learning philosophy is against practice exams. We were encouraged to write scathing reviews for his RMP profile to rip him apart because Wilson is a sadist whose goal is to send students to therapy.",
#     "createdByUser": false,
#     "date": "2024-06-01 23:33:21 +0000 UTC",
#     "difficultyRating": 5,
#     "isForCredit": true,
#     "qualityRating": 1,
#     "textbookUse": -1,
#     "wouldTakeAgain": null,
#     "tid": "2936075"
#   },
#   {
#     "attendanceMandatory": "mandatory",
#     "class": "COMPSCI240",
#     "comment": "Wilson is an absolute villain of a professor, the most unhelpful CS teacher we were unlucky to have. His poor attitude towards teaching was prevalent from the beginning, and it's clear his main goal was for us to learn nothing by giving condescending answers to students who put thorough effort. Overall, not someone we'd take classes with again.",
#     "createdByUser": false,
#     "date": "2024-05-31 23:37:09 +0000 UTC",
#     "difficultyRating": 5,
#     "isForCredit": true,
#     "qualityRating": 1,
#     "textbookUse": -1,
#     "wouldTakeAgain": null,
#     "tid": "2936075"
#   },
#   {
#     "attendanceMandatory": "non mandatory",
#     "class": "COMPSCI240",
#     "comment": "At the start of the semester he talks about how participation is 10% of the grade and achieving the 10% isn't that challenging: just visit the discussion hours, post/answer some questions of piazza and do some class questions. However at the end of the semester you end up with half the grade. EXAMS ARE HARD. LECTURES ARE DISORGANIZED.",
#     "createdByUser": false,
#     "date": "2024-05-26 09:25:33 +0000 UTC",
#     "difficultyRating": 5,
#     "isForCredit": true,
#     "qualityRating": 1,
#     "textbookUse": -1,
#     "wouldTakeAgain": null,
#     "tid": "2936075"
#   },
#   {
#     "attendanceMandatory": "mandatory",
#     "class": "Info150",
#     "comment": "just a miserable guy. useless classes, his lectures were basically just him saying \"this should be obvious\" to material that's clearly new to some students. rude to classmates on piazza & he intentionally makes work harder than it needs to be so he's not 'spoonfeeding' students. if you ask a question you'll get a condescending answer ",
#     "createdByUser": false,
#     "date": "2024-05-24 01:51:26 +0000 UTC",
#     "difficultyRating": 4,
#     "isForCredit": true,
#     "qualityRating": 1,
#     "textbookUse": -1,
#     "wouldTakeAgain": null,
#     "tid": "2936075"
#   },
#   {
#     "attendanceMandatory": "non mandatory",
#     "class": "CS240",
#     "comment": "Such a disappointment to see Mark Wilson get hired by CICS. He doesn't seem like a nice person and just has no charisma whatsoever. I consider myself a student who's willing to go the extra mile but if Wilson is going to silence student concerns and and refuse to give enough review material for a test-heavy class like CS240, it looks ugly on him.",
#     "createdByUser": false,
#     "date": "2024-05-21 21:28:55 +0000 UTC",
#     "difficultyRating": 5,
#     "isForCredit": true,
#     "qualityRating": 1,
#     "textbookUse": -1,
#     "wouldTakeAgain": null,
#     "tid": "2936075"
#   },
#   {
#     "attendanceMandatory": "mandatory",
#     "class": "COMPSCI240",
#     "comment": "I think he's fine. By no means the best professor but I never found him to be condescending, really. Lectures started off good but kind of declined in quality as the material became more abstract. Work was honestly graded pretty leniently, but it's unfortunate that our final was 40% OF OUR GRADE. Just go to labs/be active and Piazza... and study...",
#     "createdByUser": false,
#     "date": "2024-05-21 21:21:41 +0000 UTC",
#     "difficultyRating": 3,
#     "isForCredit": true,
#     "qualityRating": 3,
#     "textbookUse": -1,
#     "wouldTakeAgain": null,
#     "tid": "2936075"
#   },
#   {
#     "attendanceMandatory": "mandatory",
#     "class": "CS240",
#     "comment": "Worst experience I ever had. He clearly did not want students to be successful. He seems to enjoy making things extra difficult and confusing. He's very condescending. Class is test heavy, but he doesn't believe in practice exams, so you do not get those to study. Expect to go to tutoring for homework, and the tutor not be able to do the problems. ",
#     "createdByUser": false,
#     "date": "2024-05-21 05:04:15 +0000 UTC",
#     "difficultyRating": 5,
#     "isForCredit": true,
#     "qualityRating": 1,
#     "textbookUse": -1,
#     "wouldTakeAgain": null,
#     "tid": "2936075"
#   },
#   {
#     "attendanceMandatory": "mandatory",
#     "class": "COMPSCI240",
#     "comment": "I know Wilson gets a lot of hate for his attitude towards students esp on Piazza but overall I had a great semester. If you sit near the front of class or engage a lot, he has lots of great knowledge to share. The midterm and final are nowhere near as hard as 250 as long as you keep up to date with the hw and lectures(!), you will probably be fine.",
#     "createdByUser": false,
#     "date": "2024-05-17 20:07:55 +0000 UTC",
#     "difficultyRating": 4,
#     "isForCredit": true,
#     "qualityRating": 5,
#     "textbookUse": -1,
#     "wouldTakeAgain": 1,
#     "tid": "2936075"
#   },
#   {
#     "attendanceMandatory": "mandatory",
#     "class": "COMPSCI240",
#     "comment": "How in the world did we spent half a semester learning topics and going over them for the final just for 80% of the topics to not be on the exam",
#     "createdByUser": false,
#     "date": "2024-05-15 23:34:08 +0000 UTC",
#     "difficultyRating": 5,
#     "isForCredit": true,
#     "qualityRating": 1,
#     "textbookUse": -1,
#     "wouldTakeAgain": null,
#     "tid": "2936075"
#   },
#   {
#     "attendanceMandatory": "mandatory",
#     "class": "Info150",
#     "comment": "Often encourage students to speak, quote, \"wrong answer is okay\" and when a student answers wrong. Proceeds to belittle them and say how wrong they were. Also, threaten students to not express their concern by belittling even more on the piazza and in class if they express concern for anything grade-related things.",
#     "createdByUser": false,
#     "date": "2024-05-15 14:56:32 +0000 UTC",
#     "difficultyRating": 5,
#     "isForCredit": true,
#     "qualityRating": 1,
#     "textbookUse": -1,
#     "wouldTakeAgain": null,
#     "tid": "2936075"
#   },
#   {
#     "attendanceMandatory": "mandatory",
#     "class": "CS240",
#     "comment": "Mark Wilson is the least suited to teach person I have ever met. I dealt with a family emergency this semester and instead of showing a modicum of understanding, Prof. Wilson berated me on Piazza and refused any leniency until I spoke with the dean. I wish I learned something about stats from this class, but unfortunately Wilson hates to help. ",
#     "createdByUser": false,
#     "date": "2024-05-15 12:26:31 +0000 UTC",
#     "difficultyRating": 5,
#     "isForCredit": true,
#     "qualityRating": 1,
#     "textbookUse": -1,
#     "wouldTakeAgain": null,
#     "tid": "2936075"
#   },
#   {
#     "attendanceMandatory": "mandatory",
#     "class": "Info150",
#     "comment": "he's the type of guy who hands out pretzels to trick-or-treaters",
#     "createdByUser": false,
#     "date": "2024-05-14 00:01:24 +0000 UTC",
#     "difficultyRating": 5,
#     "isForCredit": true,
#     "qualityRating": 1,
#     "textbookUse": -1,
#     "wouldTakeAgain": null,
#     "tid": "2936075"
#   },
#   {
#     "attendanceMandatory": "non mandatory",
#     "class": "COMPSCI240",
#     "comment": "Watching Wilson getting multiple instances of reasonable vitriol from students during his first semester teaching 240 and getting demoted from Senior Lecturer to Part-Time Senior Lecturer was a major schadenfreude moment for everyone who took 240 with him because the complaints against him prove that his ego is larger than his wealth of knowledge.",
#     "createdByUser": false,
#     "date": "2024-05-06 03:15:24 +0000 UTC",
#     "difficultyRating": 5,
#     "isForCredit": true,
#     "qualityRating": 1,
#     "textbookUse": -1,
#     "wouldTakeAgain": null,
#     "tid": "2936075"
#   },
#   {
#     "attendanceMandatory": "non mandatory",
#     "class": "COMPSCI240",
#     "comment": "Wilson struggles to acknowledge student concerns and actively takes pride in embarrassing students who ask for help. It is honestly unacceptable how a rude professor with too many grudges like him is repeating mistakes of replying to genuine questions with \"stop wasting my time\" to hamper learning. Truly a villain, both as a professor and a person.",
#     "createdByUser": false,
#     "date": "2024-05-06 03:05:17 +0000 UTC",
#     "difficultyRating": 5,
#     "isForCredit": true,
#     "qualityRating": 1,
#     "textbookUse": -1,
#     "wouldTakeAgain": null,
#     "tid": "2936075"
#   },
#   {
#     "attendanceMandatory": "non mandatory",
#     "class": "COMPSCI240",
#     "comment": "Mark Wilson being forced to step down from teaching CS240 in the fall of 2024 was a top schadenfreude moment for me because the ugly reality is that Wilson is a horrible person who should've gotten his teaching rights revoked sooner rather than later due to his serious anger issues, lack of enthusiasm, and the subpar word choice in his online blog.",
#     "createdByUser": false,
#     "date": "2024-05-06 02:47:18 +0000 UTC",
#     "difficultyRating": 5,
#     "isForCredit": true,
#     "qualityRating": 1,
#     "textbookUse": -1,
#     "wouldTakeAgain": null,
#     "tid": "2936075"
#   },
#   {
#     "attendanceMandatory": "non mandatory",
#     "class": "COMPSCI240",
#     "comment": "hes ok",
#     "createdByUser": false,
#     "date": "2024-04-24 20:22:33 +0000 UTC",
#     "difficultyRating": 5,
#     "isForCredit": true,
#     "qualityRating": 1,
#     "textbookUse": 3,
#     "wouldTakeAgain": null,
#     "tid": "2936075"
#   },
#   {
#     "attendanceMandatory": "non mandatory",
#     "class": "COMPSCI240",
#     "comment": "Well, well, well...it would appear Mark Wilson's rude and disrespectful behavior towards colleagues and students alike only led karma to get back at him by forcing him to step down from teaching CS240 in the fall of 2024. I'd love to see Tim Richards get promoted to Professor and hopefully for Wilson to get permanently blacklisted from his job.",
#     "createdByUser": false,
#     "date": "2024-04-22 13:48:02 +0000 UTC",
#     "difficultyRating": 5,
#     "isForCredit": true,
#     "qualityRating": 1,
#     "textbookUse": -1,
#     "wouldTakeAgain": null,
#     "tid": "2936075"
#   },
#   {
#     "attendanceMandatory": "non mandatory",
#     "class": "CS240",
#     "comment": "Schadenfreude and Karma had a baby, and their son Mark Wilson got all grown up and hired by CICS. He clearly didn't care about student success and learning, and the word choice in his blog profile was a clear attempt to prove he hates teaching. NOBODY uses the phrase \"acceptable lower bound\" in their profile, except for a tool like Wilson.",
#     "createdByUser": false,
#     "date": "2024-04-21 13:12:46 +0000 UTC",
#     "difficultyRating": 5,
#     "isForCredit": true,
#     "qualityRating": 1,
#     "textbookUse": -1,
#     "wouldTakeAgain": null,
#     "tid": "2936075"
#   },
#   {
#     "attendanceMandatory": "mandatory",
#     "class": "CS240",
#     "comment": "Such a disappointment that Mark Wilson got hired by CICS. He doesn't seem like a very nice person and just has no charisma whatsoever. My only consolation is him being forced to step down from teaching 240 in the fall of 2024 after getting lots of reasonable vitriol from students due to his unwillingness to listen to genuine student concerns.",
#     "createdByUser": false,
#     "date": "2024-04-20 20:08:37 +0000 UTC",
#     "difficultyRating": 5,
#     "isForCredit": true,
#     "qualityRating": 1,
#     "textbookUse": -1,
#     "wouldTakeAgain": null,
#     "tid": "2936075"
#   },
#   {
#     "attendanceMandatory": "non mandatory",
#     "class": "CS240",
#     "comment": "I've seriously never seen someone with a bigger superiority complex than Mark Wilson. No surprise his blatant narcissism resulted in him being the most reviled male computer science instructor on the planet. Tim Richards is a fantastic stand up guy. Down to earth, humble, kind, charismatic, telegenic. All attributes Wilson sadly does not possess.",
#     "createdByUser": false,
#     "date": "2024-04-12 15:09:46 +0000 UTC",
#     "difficultyRating": 5,
#     "isForCredit": true,
#     "qualityRating": 1,
#     "textbookUse": -1,
#     "wouldTakeAgain": null,
#     "tid": "2936075"
#   },
#   {
#     "attendanceMandatory": "non mandatory",
#     "class": "COMPSCI240",
#     "comment": "Mark Wilson is, without doubt, among THE least deserving person to ever get hired by CICS in years. He was disrespectful and sour to students who genuinely wanted to learn the subject matter, and it's clear he hated teaching. No wonder he was forced to step down from teaching CS240 in the Fall of 2024 and was therefore replaced by Andrew Lan.",
#     "createdByUser": false,
#     "date": "2024-04-11 15:22:16 +0000 UTC",
#     "difficultyRating": 5,
#     "isForCredit": true,
#     "qualityRating": 1,
#     "textbookUse": -1,
#     "wouldTakeAgain": null,
#     "tid": "2936075"
#   },
#   {
#     "attendanceMandatory": "non mandatory",
#     "class": "COMPSCI240",
#     "comment": "Ignore the 5-star review; it clearly came from Mark Wilson himself. I've had some professors that sucked in some way before, but Wilson is the only one I'd give the middle finger to. Rude, terrible at crafting feasible exams, refuses to listen to reasonable concerns from students, and hates teaching. I would be cheering loudly if he gets laid off.",
#     "createdByUser": false,
#     "date": "2024-03-04 16:59:06 +0000 UTC",
#     "difficultyRating": 5,
#     "isForCredit": true,
#     "qualityRating": 1,
#     "textbookUse": -1,
#     "wouldTakeAgain": null,
#     "tid": "2936075"
#   },
#   {
#     "attendanceMandatory": "mandatory",
#     "class": "CS240",
#     "comment": "Do not this course with Mark Wilson. He is almost entirely incapable of receiving any form of feedback for his questions, gaslights students on his discussion posts, zooms through the material without really explaining or teaching any of it (and doesn't answer questions well if it all), and is overall just generally incapable and as a professor.",
#     "createdByUser": false,
#     "date": "2024-03-01 16:47:04 +0000 UTC",
#     "difficultyRating": 5,
#     "isForCredit": true,
#     "qualityRating": 1,
#     "textbookUse": -1,
#     "wouldTakeAgain": null,
#     "tid": "2936075"
#   },
#   {
#     "attendanceMandatory": "mandatory",
#     "class": "CS240",
#     "comment": "Wilson is a patronizing individual who always seemed bitter when students didn't immediately understand the topic he was teaching for the day. Workload was not feasible at all as HWs for his section took 20 hrs/wk.\nThere's hardly any partial credit on the exams, and he won't help if you approach him, no matter how much effort you put into the HWs.",
#     "createdByUser": false,
#     "date": "2024-03-01 06:12:52 +0000 UTC",
#     "difficultyRating": 5,
#     "isForCredit": true,
#     "qualityRating": 1,
#     "textbookUse": -1,
#     "wouldTakeAgain": null,
#     "tid": "2936075"
#   },
#   {
#     "attendanceMandatory": "non mandatory",
#     "class": "COMPSCI240",
#     "comment": "I really do not like review bombing professors, but I had to do this for Mark Wilson because the strong consensus is that Wilson is the embodiment of a brash and rude CICS instructor who cares more about \nstomping on malnourished students than putting in thorough effort to help students learn the subject matter. He's tough, and not in a good way.",
#     "createdByUser": false,
#     "date": "2024-03-01 06:07:36 +0000 UTC",
#     "difficultyRating": 5,
#     "isForCredit": true,
#     "qualityRating": 1,
#     "textbookUse": -1,
#     "wouldTakeAgain": null,
#     "tid": "2936075"
#   },
#   {
#     "attendanceMandatory": "non mandatory",
#     "class": "CS240",
#     "comment": "Because of the elementary lectures and practice, practicing with the optional textbook questions is the only reliable way to guarantee your success. The only well-designed exam was the final, both M1 and M2 had 90% cookie-cutter questions testing your speed rather than comprehension. The final required actual critical thinking and gave ample time.",
#     "createdByUser": false,
#     "date": "2024-02-27 12:22:20 +0000 UTC",
#     "difficultyRating": 4,
#     "isForCredit": true,
#     "qualityRating": 2,
#     "textbookUse": -1,
#     "wouldTakeAgain": null,
#     "tid": "2936075"
#   },
#   {
#     "attendanceMandatory": "non mandatory",
#     "class": "COMPSCI240",
#     "comment": "Wilson has an extravagant superiority complex that is quite evident in the way he takes pleasure in doing students dirty whenever they had reasonable concerns to voice on Piazza or tried to get in touch with him in office hours. He is definitely the example of the stereotypical CS professor who hates pedagogy and thinks all his students are lazy.",
#     "createdByUser": false,
#     "date": "2024-02-26 13:30:01 +0000 UTC",
#     "difficultyRating": 5,
#     "isForCredit": true,
#     "qualityRating": 1,
#     "textbookUse": -1,
#     "wouldTakeAgain": null,
#     "tid": "2936075"
#   },
#   {
#     "attendanceMandatory": "mandatory",
#     "class": "CS240",
#     "comment": "A straight up bully. Wilson never admit he's wrong, resents having students, and thinks he's superior to everyone, including his colleagues. Will not offer his wealth of knowledge but will rather call everything easy and expect students to \"know it\". He would rather publicly do students dirty than admit that he's wrong. He needs to quit teaching.",
#     "createdByUser": false,
#     "date": "2024-02-26 13:24:54 +0000 UTC",
#     "difficultyRating": 5,
#     "isForCredit": true,
#     "qualityRating": 1,
#     "textbookUse": -1,
#     "wouldTakeAgain": null,
#     "tid": "2936075"
#   },
#   {
#     "attendanceMandatory": "mandatory",
#     "class": "CS240",
#     "comment": "Wilson 240 was an incredibly frustrating memory for me. I only heard horror stories about him going in, and my experience with this class matched all of them. Wilson was clearly lacking in social skills, and he held grudges against students who were genuinely trying to learn something new. Very unprofessional experience in this class. Stay away.",
#     "createdByUser": false,
#     "date": "2024-02-23 19:59:43 +0000 UTC",
#     "difficultyRating": 5,
#     "isForCredit": true,
#     "qualityRating": 1,
#     "textbookUse": -1,
#     "wouldTakeAgain": null,
#     "tid": "2936075"
#   },
#   {
#     "attendanceMandatory": "mandatory",
#     "class": "CS240",
#     "comment": "Wow, this guy has no respect towards any CS student. If you have any question regarding your pathway or reasonable concern to voice, don't expect Wilson to help or listen to you. The big red flag about Wilson is he calls everything easy instead of realizing students are learning something new in lectures and refuses to offer his wealth of knowledge",
#     "createdByUser": false,
#     "date": "2024-02-16 02:11:01 +0000 UTC",
#     "difficultyRating": 5,
#     "isForCredit": true,
#     "qualityRating": 1,
#     "textbookUse": -1,
#     "wouldTakeAgain": null,
#     "tid": "2936075"
#   },
#   {
#     "attendanceMandatory": "non mandatory",
#     "class": "COMPSCI240",
#     "comment": "Greedy with how he grades his students and won't admit that he is wrong. With how bad many people did on the midterms he turns around and says \"the averages were similar to the other section\" instead of overhauling the curriculum. Feels like Wilson is on a high horse and is unwilling to answer questions, or if he does he tends to have no patience.",
#     "createdByUser": false,
#     "date": "2024-02-08 16:48:16 +0000 UTC",
#     "difficultyRating": 5,
#     "isForCredit": true,
#     "qualityRating": 1,
#     "textbookUse": -1,
#     "wouldTakeAgain": null,
#     "tid": "2936075"
#   },
#   {
#     "attendanceMandatory": "non mandatory",
#     "class": "CS240",
#     "comment": "Terrible resources for students, refused to release solutions for practice exams because he considers it cheating and saw all his students as lazy. No other resources besides slides are available outside of class. Personally I think his course philosophy is pedagogically unsound, and I only got by using memory for exams which quickly left my head.",
#     "createdByUser": false,
#     "date": "2024-02-08 16:42:08 +0000 UTC",
#     "difficultyRating": 5,
#     "isForCredit": true,
#     "qualityRating": 1,
#     "textbookUse": -1,
#     "wouldTakeAgain": null,
#     "tid": "2936075"
#   },
#   {
#     "attendanceMandatory": "non mandatory",
#     "class": "CS240",
#     "comment": "Difficult and excruciating class. Wilson does not have reasonable expectations but rather has a deplorable personality. He expects students to know everything by calling everything easy in lectures and refusing to offer his wealth of knowledge. He also has no regard for student learning or success. The topics sound interesting, but not with Wilson.",
#     "createdByUser": false,
#     "date": "2024-02-07 18:46:45 +0000 UTC",
#     "difficultyRating": 5,
#     "isForCredit": true,
#     "qualityRating": 1,
#     "textbookUse": -1,
#     "wouldTakeAgain": null,
#     "tid": "2936075"
#   },
#   {
#     "attendanceMandatory": "non mandatory",
#     "class": "CS240",
#     "comment": "Mark Wilson made CS240 completely unbearable. I think we're all mature enough to know that professors can't \"spoonfeed\" students, but tbh all of his rude replies of Piazza have done more harm than good and proved he doesn't want to offer his wealth of knowledge. Grading policies for homeworks and exams only worked against students. Don't take!",
#     "createdByUser": false,
#     "date": "2024-02-04 03:07:03 +0000 UTC",
#     "difficultyRating": 5,
#     "isForCredit": true,
#     "qualityRating": 1,
#     "textbookUse": -1,
#     "wouldTakeAgain": null,
#     "tid": "2936075"
#   },
#   {
#     "attendanceMandatory": "non mandatory",
#     "class": "COMPSCI240",
#     "comment": "If you don't believe Mark Wilson is a lousy lecture, calibrate your opinion again and rewatch his YouTube videos because all of his videos prove that he hates his job and has no idea how to offer his knowledge in a way that seems reasonable. In the physical classroom for 240, he puts his students beneath him and clearly feels superior about it.",
#     "createdByUser": false,
#     "date": "2024-02-01 21:27:39 +0000 UTC",
#     "difficultyRating": 5,
#     "isForCredit": true,
#     "qualityRating": 1,
#     "textbookUse": -1,
#     "wouldTakeAgain": null,
#     "tid": "2936075"
#   },
#   {
#     "attendanceMandatory": "non mandatory",
#     "class": "COMPSCI240",
#     "comment": "Wilson doesn't get it. He doesn't take note of student's strengths and weaknesses, take time to explain concepts, check whether his explanations make sense, or believe in a reasonable workload. And he doesn't seem to care. Conversely, he seems to enjoy not caring about his students. He has no business to teach despite his wealth of knowledge.",
#     "createdByUser": false,
#     "date": "2024-02-01 21:23:12 +0000 UTC",
#     "difficultyRating": 5,
#     "isForCredit": true,
#     "qualityRating": 1,
#     "textbookUse": -1,
#     "wouldTakeAgain": null,
#     "tid": "2936075"
#   },
#   {
#     "attendanceMandatory": "non mandatory",
#     "class": "COMPSCI240",
#     "comment": "Wilson is an elitist snob. He clearly considers \"normal\" students beneath him and thinks it his mission to \"weed them out\". And all he really cares about is research. So it's not surprising that he treats students differently as a supervisor. It just makes him even worse of a person, because duplicity is repulsive, and it's clear he hates pedagogy.",
#     "createdByUser": false,
#     "date": "2024-02-01 21:21:21 +0000 UTC",
#     "difficultyRating": 5,
#     "isForCredit": true,
#     "qualityRating": 1,
#     "textbookUse": -1,
#     "wouldTakeAgain": null,
#     "tid": "2936075"
#   },
#   {
#     "attendanceMandatory": "non mandatory",
#     "class": "CS240",
#     "comment": "Unlike what Wilson thinks, not all of his students are lazy. I'm a CS major with all A's in CS but if he doesn't care, then why should we care? He is the most uninspiring lecturer I've ever had and was rude and difficult to approach since he assumed his students are lazy and have poor work ethics, which he uses as an excuse for his weak pedagogy.",
#     "createdByUser": false,
#     "date": "2024-02-01 21:14:20 +0000 UTC",
#     "difficultyRating": 5,
#     "isForCredit": true,
#     "qualityRating": 1,
#     "textbookUse": -1,
#     "wouldTakeAgain": null,
#     "tid": "2936075"
#   },
#   {
#     "attendanceMandatory": "non mandatory",
#     "class": "CS240",
#     "comment": "You know it's a red flag when a professor hates his job of delivering pedagogically sound lectures. There is a reason everyone hated Wilson 240. He has a pattern of teaching a class and fully revamping the class structure to be 100x as hard, getting butthurt when people complain or express reasonable concerns, and repeating the mistakes anyway.",
#     "createdByUser": false,
#     "date": "2024-01-28 14:09:23 +0000 UTC",
#     "difficultyRating": 5,
#     "isForCredit": true,
#     "qualityRating": 1,
#     "textbookUse": -1,
#     "wouldTakeAgain": null,
#     "tid": "2936075"
#   },
#   {
#     "attendanceMandatory": "mandatory",
#     "class": "COMPSCI240",
#     "comment": "You know its bad when people are saying they rather take discrete/proofs rather than 240 with Wilson",
#     "createdByUser": false,
#     "date": "2024-01-27 01:54:40 +0000 UTC",
#     "difficultyRating": 5,
#     "isForCredit": true,
#     "qualityRating": 1,
#     "textbookUse": -1,
#     "wouldTakeAgain": null,
#     "tid": "2936075"
#   },
#   {
#     "attendanceMandatory": "non mandatory",
#     "class": "COMPSCI240",
#     "comment": "CS240 with Mark Wilson was the worst memory for me. There was not much to learn. Many students have voiced complaints about his 240 class because he was livid when students asked genuine questions. Discussions and office hours were also poorly run, but he refused to take the class's weaknesses as a reflection on his pedagogy. Very unpleasant class.",
#     "createdByUser": false,
#     "date": "2024-01-27 00:06:36 +0000 UTC",
#     "difficultyRating": 5,
#     "isForCredit": true,
#     "qualityRating": 1,
#     "textbookUse": -1,
#     "wouldTakeAgain": null,
#     "tid": "2936075"
#   },
#   {
#     "attendanceMandatory": "non mandatory",
#     "class": "CS240",
#     "comment": "I don't know what grudges this guy has against the students he's grading but his nitpicky grading policy for exams and HWs is absolutely absurd.",
#     "createdByUser": false,
#     "date": "2024-01-17 20:18:10 +0000 UTC",
#     "difficultyRating": 5,
#     "isForCredit": true,
#     "qualityRating": 1,
#     "textbookUse": -1,
#     "wouldTakeAgain": null,
#     "tid": "2936075"
#   },
#   {
#     "attendanceMandatory": "non mandatory",
#     "class": "CS240",
#     "comment": "Wilson 240 is the single worst class I've ever taken. It's unreal how Wilson's right to teach hasn't been revoked yet, given his mismanagement of 240 and general lack of kindness and compassion. And his handwriting is poor. In general, he's not a good person. For the amount of time I grinded for this class, it should be at least 6 credits.",
#     "createdByUser": false,
#     "date": "2024-01-13 17:32:14 +0000 UTC",
#     "difficultyRating": 5,
#     "isForCredit": true,
#     "qualityRating": 1,
#     "textbookUse": -1,
#     "wouldTakeAgain": null,
#     "tid": "2936075"
#   },
#   {
#     "attendanceMandatory": "non mandatory",
#     "class": "COMPSCI240",
#     "comment": "Wilson is a prime example of a very unapproachable CS instructor. He is not patient with student questions and seems to blame his students for the low exam averages instead of taking responsibility for his actions.",
#     "createdByUser": false,
#     "date": "2024-01-11 15:22:41 +0000 UTC",
#     "difficultyRating": 5,
#     "isForCredit": true,
#     "qualityRating": 1,
#     "textbookUse": -1,
#     "wouldTakeAgain": null,
#     "tid": "2936075"
#   },
#   {
#     "attendanceMandatory": "non mandatory",
#     "class": "COMPSCI240",
#     "comment": "Wilson knows the material but doesn't know how to explain it in robustly. No effort is put for students to succeed. Is always passive-aggressive in his responses when you contact him for help. The whole course staff for his 240 section is woefully incompetent. Take another instructor if you can.",
#     "createdByUser": false,
#     "date": "2024-01-10 17:08:02 +0000 UTC",
#     "difficultyRating": 5,
#     "isForCredit": true,
#     "qualityRating": 1,
#     "textbookUse": -1,
#     "wouldTakeAgain": null,
#     "tid": "2936075"
#   },
#   {
#     "attendanceMandatory": "non mandatory",
#     "class": "CS240",
#     "comment": "You would expect that once you hit rock bottom, there is no way to go down even further, but trust me, Mark Wilson will find a way to make that happen.",
#     "createdByUser": false,
#     "date": "2024-01-10 04:12:57 +0000 UTC",
#     "difficultyRating": 4,
#     "isForCredit": true,
#     "qualityRating": 1,
#     "textbookUse": -1,
#     "wouldTakeAgain": null,
#     "tid": "2936075"
#   },
#   {
#     "attendanceMandatory": "non mandatory",
#     "class": "CS240",
#     "comment": "I actually did well in this class. That being said, DO NOT TAKE 240 with Wilson if you have a choice. He is very rude, he never gives good feedback. His philosophy is basically \"his way or the highway\". I think he should do better because from what I've heard, Wilson hates his job. Many students would benefit by \"not having Wilson as a professor.\"",
#     "createdByUser": false,
#     "date": "2024-01-08 23:35:58 +0000 UTC",
#     "difficultyRating": 5,
#     "isForCredit": true,
#     "qualityRating": 1,
#     "textbookUse": -1,
#     "wouldTakeAgain": null,
#     "tid": "2936075"
#   },
#   {
#     "attendanceMandatory": "non mandatory",
#     "class": "COMPSCI240",
#     "comment": "Ironically, the only uncertainty I faced in this class was my final grade. Wilson's patronizing attitude, unrewarding lectures, and curveball exams were all certainties.",
#     "createdByUser": false,
#     "date": "2024-01-07 18:08:04 +0000 UTC",
#     "difficultyRating": 1,
#     "isForCredit": true,
#     "qualityRating": 1,
#     "textbookUse": -1,
#     "wouldTakeAgain": null,
#     "tid": "2936075"
#   },
#   {
#     "attendanceMandatory": "non mandatory",
#     "class": "COMPSCI240",
#     "comment": "Abysmal pedagogy, prioritizes drama creation over helping students learn. Zero flexibility in how to show work for homeworks and exams. Has his TAs do all his work for him. Refuses to release practice exam solutions. Rude, full of himself, his learning philosophy is basically \"his way or the highway.\" Nothing but bad things to say about him.",
#     "createdByUser": false,
#     "date": "2024-01-04 16:25:18 +0000 UTC",
#     "difficultyRating": 5,
#     "isForCredit": true,
#     "qualityRating": 1,
#     "textbookUse": -1,
#     "wouldTakeAgain": null,
#     "tid": "2936075"
#   },
#   {
#     "attendanceMandatory": "non mandatory",
#     "class": "CS240",
#     "comment": "Professor Wilson is the most ego-motivated CS instructor I have ever had at UMass. He is passive-aggressive to the entire class for his own entertainment. His unwillingness to provide thorough explanations and share his wealth of knowledge both prove that he hates teaching. Overall, Wilson embodies someone I would never take classes with willingly.",
#     "createdByUser": false,
#     "date": "2023-12-30 18:44:22 +0000 UTC",
#     "difficultyRating": 5,
#     "isForCredit": true,
#     "qualityRating": 1,
#     "textbookUse": -1,
#     "wouldTakeAgain": null,
#     "tid": "2936075"
#   },
#   {
#     "attendanceMandatory": "non mandatory",
#     "class": "CS240",
#     "comment": "Mark Wilson is known to be a universally hated CICS instructor for a reason: he's highly unorganized, short-tempered, and has unreasonable grading and exam policies. He is also not compassionate and can be very rude. Frankly, I got a way higher grade in Marius 220 and Marius 311 than this class. Take that into perspective: two Marius classes!",
#     "createdByUser": false,
#     "date": "2023-12-30 18:21:40 +0000 UTC",
#     "difficultyRating": 5,
#     "isForCredit": true,
#     "qualityRating": 1,
#     "textbookUse": -1,
#     "wouldTakeAgain": null,
#     "tid": "2936075"
#   },
#   {
#     "attendanceMandatory": "non mandatory",
#     "class": "CS240",
#     "comment": "This class was made unnecessarily hard. The main issue is not that the material was hard - it's the repeated organizational failures on Wilson's part with no willingness to change. Exams were not properly booked, ALL questions were banned during exams, and little to no materials/resources were provided (very few practice tests).",
#     "createdByUser": false,
#     "date": "2023-12-27 21:07:51 +0000 UTC",
#     "difficultyRating": 5,
#     "isForCredit": true,
#     "qualityRating": 1,
#     "textbookUse": -1,
#     "wouldTakeAgain": null,
#     "tid": "2936075"
#   },
#   {
#     "attendanceMandatory": "non mandatory",
#     "class": "COMPSCI240",
#     "comment": "Wilson did a great job in making a previously easy class harder to do well on. His recorded videos were weak and did not do a good job explaining concepts in detail. The exams were also hard, there was no flexibility in how to show work for the problems, so if your intuition diverged from how he wanted you to show work, you were screwed. Awful.",
#     "createdByUser": false,
#     "date": "2023-12-24 18:39:26 +0000 UTC",
#     "difficultyRating": 5,
#     "isForCredit": true,
#     "qualityRating": 1,
#     "textbookUse": -1,
#     "wouldTakeAgain": null,
#     "tid": "2936075"
#   },
#   {
#     "attendanceMandatory": "non mandatory",
#     "class": "CS240",
#     "comment": "Wilson is straight up evil, rude, and clearly needs to learn to treat colleagues and students with respect. The way he ran 240 this fall was so bad I had to bring this up to the CICS dean. In the end we were encouraged to write bad reviews once a profile opened for Wilson. Even people who are doing well in the class didn't like him.",
#     "createdByUser": false,
#     "date": "2023-12-22 21:07:47 +0000 UTC",
#     "difficultyRating": 5,
#     "isForCredit": true,
#     "qualityRating": 1,
#     "textbookUse": -1,
#     "wouldTakeAgain": null,
#     "tid": "2936075"
#   },
#   {
#     "attendanceMandatory": "non mandatory",
#     "class": "CS240",
#     "comment": "This class sucked in the fall of 2023. I'm convinced Mark Wilson ran this class poorly with the ulterior motive to send students to therapy instead of help them learn.",
#     "createdByUser": false,
#     "date": "2023-12-22 17:22:25 +0000 UTC",
#     "difficultyRating": 5,
#     "isForCredit": true,
#     "qualityRating": 1,
#     "textbookUse": -1,
#     "wouldTakeAgain": null,
#     "tid": "2936075"
#   },
#   {
#     "attendanceMandatory": "non mandatory",
#     "class": "COMPSCI240",
#     "comment": "I actually did well in this class. My problem is with Wilson as a person. He won't admit when he's wrong, when he objectively is and he is very rude to his students and gets butthurt if he even gets a hint that they might think the way he ran the curriculum for 240 was problematic. Unless you're a sycophant he's really just a literal villain.",
#     "createdByUser": false,
#     "date": "2023-12-22 17:16:34 +0000 UTC",
#     "difficultyRating": 5,
#     "isForCredit": true,
#     "qualityRating": 1,
#     "textbookUse": -1,
#     "wouldTakeAgain": null,
#     "tid": "2936075"
#   },
#   {
#     "attendanceMandatory": "non mandatory",
#     "class": "COMPSCI240",
#     "comment": "I am very sorry you have to take this class. The entire 240 class is under fire since he came. He says he didn't change the curriculum, but you'll find out very soon that you are going to spend all your time on this class. And for the exams, if you know how to solve all the book questions, blindfolded, id say you'd be lucky to get C-. Enjoy! ",
#     "createdByUser": false,
#     "date": "2023-12-21 21:14:46 +0000 UTC",
#     "difficultyRating": 5,
#     "isForCredit": true,
#     "qualityRating": 1,
#     "textbookUse": -1,
#     "wouldTakeAgain": null,
#     "tid": "2936075"
#   },
#   {
#     "attendanceMandatory": "",
#     "class": "COMPSCI240",
#     "comment": "Totally sucks. Mark Wilson knows his stuff but any genuine question asked in his office hours is met with nothing but passive-aggressive non-answers. Won't let anyone get on his good side so make sure to be the best self-studier ever. If you think you can charm the devil, take a class with Wilson. Otherwise, you're better off avoiding him for 240.",
#     "createdByUser": false,
#     "date": "2023-12-21 17:20:29 +0000 UTC",
#     "difficultyRating": 4,
#     "isForCredit": true,
#     "qualityRating": 1,
#     "textbookUse": null,
#     "wouldTakeAgain": null,
#     "tid": "2936075"
#   },
#   {
#     "attendanceMandatory": "non mandatory",
#     "class": "COMPSCI240",
#     "comment": "I'd like to start off with something he said on Piazza: \n\n\"A) Please stop wasting my time with these discussions. I get notifications that distract me from setting the grades. B) As I said, student input will not be a consideration - we are professionals paid to do this job. When you teach, do it your way.\"\n\nDo I really need to say much more?",
#     "createdByUser": false,
#     "date": "2023-12-19 20:41:34 +0000 UTC",
#     "difficultyRating": 5,
#     "isForCredit": true,
#     "qualityRating": 1,
#     "textbookUse": -1,
#     "wouldTakeAgain": null,
#     "tid": "2936075"
#   },
#   {
#     "attendanceMandatory": "non mandatory",
#     "class": "COMPSCI240",
#     "comment": "Exams are 70% of your grade and some questions are very abstract and honestly don't test your knowledge of the content. Hard to prep for exams given that there is little to no practice material. Overall poorly run course with very small amounts of lecture content being useful.",
#     "createdByUser": false,
#     "date": "2023-12-18 19:57:39 +0000 UTC",
#     "difficultyRating": 5,
#     "isForCredit": true,
#     "qualityRating": 1,
#     "textbookUse": -1,
#     "wouldTakeAgain": null,
#     "tid": "2936075"
#   },
#   {
#     "attendanceMandatory": "non mandatory",
#     "class": "COMPSCI240",
#     "comment": "Wilson berates students who ask genuine questions. His lectures are dry and not worth going to because no examples were given for concepts like Bayes' theorem, and his handwriting looks like that of a toddler. Practice exam solutions are never released. TA and instructor office hours are terribly run. I learned more from YouTube than his lectures.",
#     "createdByUser": false,
#     "date": "2023-12-17 05:27:15 +0000 UTC",
#     "difficultyRating": 5,
#     "isForCredit": true,
#     "qualityRating": 1,
#     "textbookUse": -1,
#     "wouldTakeAgain": null,
#     "tid": "2936075"
#   },
#   {
#     "attendanceMandatory": "non mandatory",
#     "class": "COMPSCI240",
#     "comment": "Mark Wilson is an absolute curse to the Manning CICS. He didn't listen to students when they were feeling burnt out, and instead of answering genuine questions on Piazza, he did nothing but repeatedly make passive-aggressive comments. The material is super interesting but 240 is not a good class if Wilson runs the curriculum for that class.",
#     "createdByUser": false,
#     "date": "2023-12-17 00:55:08 +0000 UTC",
#     "difficultyRating": 5,
#     "isForCredit": true,
#     "qualityRating": 1,
#     "textbookUse": -1,
#     "wouldTakeAgain": null,
#     "tid": "2936075"
#   },
#   {
#     "attendanceMandatory": "non mandatory",
#     "class": "COMPSCI240",
# ...
#     "createdByUser": false,
#     "date": "2023-12-10 08:11:52 +0000 UTC",
#     "difficultyRating": 5,
#     "isForCredit": true,
#     "qualityRating": 1,
#     "textbookUse": 3,
#     "wouldTakeAgain": null,
#     "tid": "2936075"
#   },
#   {
#     "attendanceMandatory": "non mandatory",
#     "class": "COMPSCI240",
#     "comment": "He is not great and this class caused me way more stress than I anticipated going into it. I do want to note that we are not done with this semester yet and I do not know if things will be scaled. Regardless, I find this professor to be very dismissive of students' concerns, which to me is the biggest problem. ",
#     "createdByUser": false,
#     "date": "2023-12-08 16:16:28 +0000 UTC",
#     "difficultyRating": 5,
#     "isForCredit": true,
#     "qualityRating": 1,
#     "textbookUse": 3,
#     "wouldTakeAgain": null,
#     "tid": "2936075"
#   },
#   {
#     "attendanceMandatory": "non mandatory",
#     "class": "COMPSCI240",
#     "comment": "DO NOT take 240 with Mark Wilson. He won't admit when he is at fault, and he will gaslight anyone who calls him out for his mistakes. The strong consensus is that Wilson is unorganized and treats students with unwarranted disrespect (shames students in class) and inflexibility (no room for creativity). I wish I could report him to the dean of CICS.",
#     "createdByUser": false,
#     "date": "2023-12-04 02:15:11 +0000 UTC",
#     "difficultyRating": 5,
#     "isForCredit": true,
#     "qualityRating": 1,
#     "textbookUse": -1,
#     "wouldTakeAgain": null,
#     "tid": "2936075"
#   },
#   {
#     "attendanceMandatory": "non mandatory",
#     "class": "CS240",
#     "comment": "Not good. I say this with all honesty, avoid Mark Wilson at all costs for 240. The subject matter is interesting. However, Mark Wilson is rude, boring, uninspiring, and makes the class material unnecessarily dry. He doesn't seem to listen to student concerns, and the learning environment in his 240 class is completely bereft of all flexibility.",
#     "createdByUser": false,
#     "date": "2023-12-03 03:54:29 +0000 UTC",
#     "difficultyRating": 5,
#     "isForCredit": true,
#     "qualityRating": 1,
#     "textbookUse": -1,
#     "wouldTakeAgain": null,
#     "tid": "2936075"
#   },
#   {
#     "attendanceMandatory": "",
#     "class": "CS240",
#     "comment": "Straight outta New Zealand to wreak havoc in umass",
#     "createdByUser": false,
#     "date": "2023-12-02 00:29:52 +0000 UTC",
#     "difficultyRating": 5,
#     "isForCredit": true,
#     "qualityRating": 1,
#     "textbookUse": null,
#     "wouldTakeAgain": null,
#     "tid": "2936075"
#   },
#   {
#     "attendanceMandatory": "non mandatory",
#     "class": "CS240",
#     "comment": "Professor Wilson somehow manages to keep making the course worse. Despite multiple students' grievances, he turns a blind eye to the problems that they bring up. He constantly points faults in their preparations and tells them not to worry since \"exam grades can be scaled\". However, the scaling is flawed, scaling high scores much more than lows.",
#     "createdByUser": false,
#     "date": "2023-12-01 02:50:36 +0000 UTC",
#     "difficultyRating": 4,
#     "isForCredit": true,
#     "qualityRating": 1,
#     "textbookUse": -1,
#     "wouldTakeAgain": null,
#     "tid": "2936075"
#   },
#   {
#     "attendanceMandatory": "non mandatory",
#     "class": "CS240",
#     "comment": "Never been the one to spew vitriol against instructors, but if a professor is rude for no reason, setting students up to learn nothing, and invalidating real student concerns, that's not a good sign, and apparently Mark Wilson embodies all 3 of these red flags. And his YouTube videos suck because they provide little coverage of practical examples.",
#     "createdByUser": false,
#     "date": "2023-11-29 16:59:18 +0000 UTC",
#     "difficultyRating": 5,
#     "isForCredit": true,
#     "qualityRating": 1,
#     "textbookUse": -1,
#     "wouldTakeAgain": null,
#     "tid": "2936075"
#   },
#   {
#     "attendanceMandatory": "non mandatory",
#     "class": "CS240",
#     "comment": "Really bad. Yes, I agree that you can't expect instructors to spoonfeed you but if a professor is lazy and hates his job or his students, they should reevaluate themselves because that attitude pretty much doesn't help anyone -- apparently that applies to Mark Wilson as well. Overall, Wilson's detached attitude made 240 harder than it should be.",
#     "createdByUser": false,
#     "date": "2023-11-28 02:26:34 +0000 UTC",
#     "difficultyRating": 4,
#     "isForCredit": true,
#     "qualityRating": 1,
#     "textbookUse": -1,
#     "wouldTakeAgain": null,
#     "tid": "2936075"
#   },
#   {
#     "attendanceMandatory": "non mandatory",
#     "class": "CS240",
#     "comment": "If you're thinking of taking him, don't.",
#     "createdByUser": false,
#     "date": "2023-11-17 03:14:40 +0000 UTC",
#     "difficultyRating": 4,
#     "isForCredit": true,
#     "qualityRating": 1,
#     "textbookUse": -1,
#     "wouldTakeAgain": null,
#     "tid": "2936075"
#   },
#   {
#     "attendanceMandatory": "non mandatory",
#     "class": "CS240",
#     "comment": "If it's 240 with him or working in a coal mine, I'd do the latter. I'm genuinely impressed it could be this bad and I wish I was only joking. Prof Wilson has made this semester a harrowing experience. Gotcha questions on exams, apathetic,disinterested, there aren't enough adjectives to describe the way this man treats people and runs his classroom.",
#     "createdByUser": false,
#     "date": "2023-11-16 22:49:02 +0000 UTC",
#     "difficultyRating": 5,
#     "isForCredit": true,
#     "qualityRating": 1,
#     "textbookUse": 3,
#     "wouldTakeAgain": null,
#     "tid": "2936075"
#   },
#   {
#     "attendanceMandatory": "non mandatory",
#     "class": "CS240",
#     "comment": "I'm not even in Mark Wilson's lecture section, and I'm still feeling the effects of his recent addition to the 240 instruction team. He is clearly the primary reason for the restructuring of the course, and our exams have been terrible. I feel like an experiment on his \"bright\" new visions for the course. Avoid at all costs. ",
#     "createdByUser": false,
#     "date": "2023-11-16 21:17:23 +0000 UTC",
#     "difficultyRating": 5,
#     "isForCredit": true,
#     "qualityRating": 1,
#     "textbookUse": -1,
#     "wouldTakeAgain": null,
#     "tid": "2936075"
#   },
#   {
#     "attendanceMandatory": "non mandatory",
#     "class": "CS240",
#     "comment": "NEVER take a class with this professor. 240 was explained in the past as the easiest out of the 200's for CS and now it has become absolute torture. I'm considering force-failing the class just to take it again because I'm at a C right now. I'm worried that because he's co-teaching again in spring 2024, the class will be the exact same. AVOID!",
#     "createdByUser": false,
#     "date": "2023-11-16 16:20:09 +0000 UTC",
#     "difficultyRating": 5,
#     "isForCredit": true,
#     "qualityRating": 1,
#     "textbookUse": -1,
#     "wouldTakeAgain": null,
#     "tid": "2936075"
#   },
#   {
#     "attendanceMandatory": "non mandatory",
#     "class": "CS240",
#     "comment": "Mark Wilson cares very little, if at all, about his job. In a blog post, he writes that his position at UMass Amherst is an \"acceptable lower bound,\" and that he will be applying for tenured positions elsewhere. Wilson has shown immense disrespect toward colleagues and students alike. It is clear that he has a misguided perception of academia.",
#     "createdByUser": false,
#     "date": "2023-11-16 02:55:19 +0000 UTC",
#     "difficultyRating": 1,
#     "isForCredit": true,
#     "qualityRating": 1,
#     "textbookUse": -1,
#     "wouldTakeAgain": null,
#     "tid": "2936075"
#   },
#   {
#     "attendanceMandatory": "non mandatory",
#     "class": "CS240",
#     "comment": "Professor Wilson can be harsh and come off as mean, but it's because he has high standards for his students and hopes for them to achieve. Don't expect a nice babysitter who will carry you to success, but do expect a fair and firm guide through statistics. The class overall is boring but that's not his fault.",
#     "createdByUser": false,
#     "date": "2023-11-16 02:45:23 +0000 UTC",
#     "difficultyRating": 3,
#     "isForCredit": true,
#     "qualityRating": 5,
#     "textbookUse": 3,
#     "wouldTakeAgain": 1,
#     "tid": "2936075"
#   },
#   {
#     "attendanceMandatory": "non mandatory",
#     "class": "CS240",
#     "comment": "Prof Wilson is hands down one of the worst professors. If you take his classes, be ready to fail. Do not expect a fair shake, do not expect to learn, do not expect to be understood, heard, appreciated or respected. The tests (worth 80% ovr) are impossible with suffocating time constraints. His classes are an elaborate torture routine.",
#     "createdByUser": false,
#     "date": "2023-11-15 22:43:10 +0000 UTC",
#     "difficultyRating": 5,
#     "isForCredit": true,
#     "qualityRating": 1,
#     "textbookUse": -1,
#     "wouldTakeAgain": null,
#     "tid": "2936075"
#   },
#   {
#     "attendanceMandatory": "non mandatory",
#     "class": "CS240",
#     "comment": "He is very enthusiastic but you would get a good sleep in his class. You won't understand a word he teaches. For weekly quizzes, there were supposed to be 2 attempts, and they couldn't figure out a way to technically do it, hence they just extended the quiz time to 3 hours. Avoid if you can. SI sessions are rather helpful and you would learn more.",
#     "createdByUser": false,
#     "date": "2023-11-14 18:49:42 +0000 UTC",
#     "difficultyRating": 5,
#     "isForCredit": true,
#     "qualityRating": 1,
#     "textbookUse": null,
#     "wouldTakeAgain": null,
#     "tid": "2936075"
#   },
#   {
#     "attendanceMandatory": "non mandatory",
#     "class": "CS240",
#     "comment": "Boring, passive aggressive, and blatantly insecure about his teaching. I wouldn't even show up if attendance was suddenly graded. Make the mistake of showing up and you'll be questioning your sobriety. 240 with Wilson is a masterclass in dissatisfaction that'll leave you questioning the entire purpose of higher education. ",
#     "createdByUser": false,
#     "date": "2023-11-13 19:05:37 +0000 UTC",
#     "difficultyRating": 3,
#     "isForCredit": true,
#     "qualityRating": 1,
#     "textbookUse": -1,
#     "wouldTakeAgain": null,
#     "tid": "2936075"
#   },
#   {
#     "attendanceMandatory": "mandatory",
#     "class": "CS240",
#     "comment": "Rude and disrespectful to our whole in-person class and honestly lazy, undoubtedly one of the most incompetent teachers I have ever had. Constantly picked on students and showed no interest in teaching whatsoever. CS240 is a required core class, but I'd recommend just picking a different teacher for the class if you have a choice.",
#     "createdByUser": false,
#     "date": "2023-11-12 00:24:59 +0000 UTC",
#     "difficultyRating": 4,
#     "isForCredit": true,
#     "qualityRating": 1,
#     "textbookUse": -1,
#     "wouldTakeAgain": null,
#     "tid": "2936075"
#   },
#   {
#     "attendanceMandatory": "mandatory",
#     "class": "CS240",
#     "comment": "240 is supposed to be an easy class but Mark Wilson is a terrible instructor and does not care about student success and learning. Rude, and learning is impossible because Prof. Wilson wants you to show work in ways that fulfill his own ego, so basically there's no flexibility in how you approach HW problems. Anyone can do a better job teaching.",
#     "createdByUser": false,
#     "date": "2023-11-10 18:13:15 +0000 UTC",
#     "difficultyRating": 3,
#     "isForCredit": true,
#     "qualityRating": 1,
#     "textbookUse": -1,
#     "wouldTakeAgain": null,
#     "tid": "2936075"
#   },
#   {
#     "attendanceMandatory": "non mandatory",
#     "class": "CS240",
#     "comment": "Wow! What to say about Mark Wilson. Nothing good that's for sure. Bad professor who blames it on his students not coming to lecture bc his lectures suck. I'm used to CS professors being sassy in piazza responses, but at least they usually answer the question. He's just plain mean. No way I'm getting better than a C, good chance I'll fail. AVOID",
#     "createdByUser": false,
#     "date": "2023-11-10 15:11:59 +0000 UTC",
#     "difficultyRating": 5,
#     "isForCredit": true,
#     "qualityRating": 1,
#     "textbookUse": null,
#     "wouldTakeAgain": null,
#     "tid": "2936075"
#   },
#   {
#     "attendanceMandatory": "non mandatory",
#     "class": "CS240",
#     "comment": "This man represents the worst of the CS department. Gave his section 60 min to do the exam rather than giving the previously agreed upon 75 min. When we realized, he had the professor from the other section apologize in his stead. Afterwards, even downplayed the impact of his error. Truly unprofessional and has a terrible personality to boot.",
#     "createdByUser": false,
#     "date": "2023-11-10 06:01:39 +0000 UTC",
#     "difficultyRating": 5,
#     "isForCredit": true,
#     "qualityRating": 1,
#     "textbookUse": 3,
#     "wouldTakeAgain": null,
#     "tid": "2936075"
#   },
#   {
#     "attendanceMandatory": "non mandatory",
#     "class": "CS240",
#     "comment": "Extremely rude and insulting to students. Attempts to lecture through vigorous hand gestures rather than actually taking the time to effectively explain concepts. On the class forum, gives off a thinly-veiled apathetic attitude with one-word, vague, unhelpful answers. Seems more disinterested in this class than anything else. Avoid at all costs. ",
#     "createdByUser": false,
#     "date": "2023-11-10 04:34:18 +0000 UTC",
#     "difficultyRating": 5,
#     "isForCredit": true,
#     "qualityRating": 1,
#     "textbookUse": 3,
#     "wouldTakeAgain": null,
#     "tid": "2936075"
#   },
#   {
#     "attendanceMandatory": "non mandatory",
#     "class": "CS240",
#     "comment": "Demands respect from students while often not affording them any. Refuses to fully admit when he made a mistake. Lambastes students when they ask what he considers \"obvious\" questions. He accidentally gave his section less time than the other on the first exam, and then downplayed it by saying that the scores between sections were similar. Avoid.",
#     "createdByUser": false,
#     "date": "2023-10-31 21:42:03 +0000 UTC",
#     "difficultyRating": 4,
#     "isForCredit": true,
#     "qualityRating": 1,
#     "textbookUse": -1,
#     "wouldTakeAgain": null,
#     "tid": "2936075"
#   },
#   {
#     "attendanceMandatory": "",
#     "class": "CS240",
#     "comment": "Professor Wilson just reads off slides and doesn't know how to explain it half of the times. Was looking forward to this class and its content, but this was a let down. Avoid him if you can.",
#     "createdByUser": false,
#     "date": "2023-10-23 19:10:56 +0000 UTC",
#     "difficultyRating": 4,
#     "isForCredit": false,
#     "qualityRating": 1,
#     "textbookUse": null,
#     "wouldTakeAgain": null,
#     "tid": "2936075"
#   },
#   {
#     "attendanceMandatory": "non mandatory",
#     "class": "CS240",
#     "comment": "Professor Wilson is condescending, Could not care less about student success. The course is poorly run, he hardly knows what's on his own slides and could not care less about how any of his students are fairing in the class. He will never take accountability for his mistakes. Downright rude on some occassions and completely negligent in all others.",
#     "createdByUser": false,
#     "date": "2023-10-20 23:04:40 +0000 UTC",
#     "difficultyRating": 4,
#     "isForCredit": true,
#     "qualityRating": 1,
#     "textbookUse": -1,
#     "wouldTakeAgain": null,
#     "tid": "2936075"
#   },
#   {
#     "attendanceMandatory": "",
#     "class": "CS240",
#     "comment": "Doesn't know how to explain the material well. He is obviously very bothered that no one shows up to the lectures, but it's because it's easier to learn the material ourselves. Also very judgmental and impatient, isn't fit to teach. ",
#     "createdByUser": false,
#     "date": "2023-10-15 15:37:35 +0000 UTC",
#     "difficultyRating": 3,
#     "isForCredit": false,
#     "qualityRating": 1,
#     "textbookUse": null,
#     "wouldTakeAgain": null,
#     "tid": "2936075"
#   }
# ]

# %%
def get_umass_professors(school_id="U2Nob29zLTE1MTM="):  # Base64 encoded "School-1513"
    headers = {
        'Authorization': 'Basic dGVzdDp0ZXN0',
        'Content-Type': 'application/json',
        'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/91.0.4472.124 Safari/537.36'
    }
    
    query = {
        "query": """
        query NewSearch($query: TeacherSearchQuery!) {
          newSearch {
            teachers(query: $query, first: 1000) {
              edges {
                node {
                  id
                  firstName
                  lastName
                  department
                }
              }
              pageInfo {
                hasNextPage
                endCursor
              }
            }
          }
        }
        """,
        "variables": {
            "query": {
                "text": "",
                "schoolID": school_id,
                "fallback": False,
                "departmentID": None
            }
        }
    }
    
    response = requests.post(
        "https://www.ratemyprofessors.com/graphql",
        json=query,
        headers=headers
    )
    
    if response.status_code == 200:
        data = response.json()
        professors = []
        
        if 'data' in data and 'newSearch' in data['data']:
            try: 
                for edge in data['data']['newSearch']['teachers']['edges']:
                    prof = edge['node']
                    # Check if 'id' is in the expected format (Base64 encoded) and decode it
                    if 'id' in prof:
                        try:
                            decoded_id = base64.b64decode(prof['id']).decode('utf-8')
                            professors.append({
                                'id': decoded_id.split('-')[1],  # Remove the "Teacher-" prefix
                                'name': f"{prof['firstName']} {prof['lastName']}",
                                'department': prof['department']
                            })
                        except Exception as e:
                            print(f"Error decoding ID for professor: {prof}, Error: {e}")
                    else:
                        print(f"Unexpected ID format for professor: {prof}")
            except Exception as e:
                print(f"Error processing data: {e}")

            print(f"Found {len(professors)} professors")
            return professors
    else:
        print(f"Error: {response.status_code}")
        print(response.text)
        return None

# Get all UMass professors
professors = get_umass_professors()

# Print first few professors to verify
if professors:
    print("\nFirst 5 professors:")
    for prof in professors[:5]:
        print(f"ID: {prof['id']}, Name: {prof['name']}, Department: {prof['department']}")
    
    # Save to CSV for future use
    df = pd.DataFrame(professors)

professor_dict = {prof['id']: prof for prof in professors}
# Out:
# Found 1000 professors
#
# First 5 professors:
# ID: 203815, Name: John Bickford, Department: Psychology
# ID: 77120, Name: Randall Phillis, Department: Biology
# ID: 1621419, Name: Laura Francis, Department: Biology
# ID: 192549, Name: Joanna Jeneralczuk, Department: Mathematics
# ID: 1617241, Name: Chris McDaniel, Department: Chemistry

# %%
ids = [id['id'] for id in professors]
reviews = []

if 'reviews' not in locals() or reviews == []:
    reviews = []
    total_reviews = 0
    teacher_count = 0
    for id in ids:
        print(id)
        new_reviews = get_all_reviews(id)
        print(len(new_reviews))
        if new_reviews:
            reviews.append(new_reviews)
            total_reviews += len(new_reviews)
            teacher_count += 1
        
        time.sleep(10)  # Wait for 10 second between each review to help the server from robot.txt
    print(f"Total teachers processed: {teacher_count}")

# Reduce reviews to get the length
reviews_length = [len(review) for review in reviews]
print(f"Total number of reviews collected: {sum(reviews_length)}")
print(f"Length of each review: {reviews_length}")
# Out:
# 203815
# 449
# 77120
# 388
# 1621419
# 370
# 192549
# 323
# 1617241
# 298
# 47704
# 280
# 887526
# 265
# 837070
# 261
# 1918813
# 269
# 2385263
# 257
# 752484
# 260
# 385698
# 240
# 287874
# 236
# 83019
# 237
# 82675
# 230
# 92488
# 223
# 83082
# 218
# 7541
# 202
# 1847647
# 202
# 2118960
# 195
# 1661417
# 191
# 59327
# 184
# 1412623
# 188
# 227364
# 184
# 101901
# 177
# 84404
# 176
# 82618
# 171
# 545173
# 173
# 92458
# 170
# 2416008
# 169
# 83243
# 168
# 98567
# 162
# 841483
# 162
# 1619359
# 163
# 77072
# 155
# 102012
# 151
# 92516
# 151
# 82779
# 148
# 82439
# 145
# 83040
# 145
# 193928
# 145
# 1760754
# 145
# 191694
# 143
# 1325070
# 134
# 2182132
# 140
# 84356
# 131
# 83050
# 131
# 191977
# 130
# 101369
# 126
# 64862
# 126
# 88142
# 124
# 100144
# 124
# 59525
# 121
# 935860
# 121
# 82723
# 120
# 2010156
# 123
# 1552014
# 114
# 82760
# 113
# 92440
# 112
# 2176331
# 117
# 2409689
# 108
# 79172
# 108
 23, 23, 23, 23, 23, 23, 23, 23, 23, 23, 23, 23, 23, 23, 23, 23, 23, 24, 24, 24, 23, 23, 23, 23, 23, 23, 23, 24, 23, 23, 24, 23, 23, 23, 22, 22, 22, 22, 25, 22, 23, 22, 23, 22, 22, 22, 22, 22, 22, 22, 22, 22, 22, 22, 22, 22, 22, 22, 22, 22, 22, 22, 22, 22, 22, 22, 22, 22, 22, 22, 25, 21, 21, 22, 21, 21, 21, 21, 21, 21, 21, 21, 23, 21, 21, 21, 21, 21, 21, 21, 21, 21, 21, 21, 21, 21, 21, 23, 21, 21, 21, 21, 21, 21, 21, 21, 21, 20, 20, 20, 20, 20, 20, 20, 20, 21, 20, 20, 20, 20, 20, 21, 21, 20, 20, 21, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 22, 20, 20, 20, 20, 20, 20, 22, 20, 20, 20, 22, 19, 19, 19, 19, 19, 19, 21, 20, 19, 19, 19, 19, 19, 25, 23, 22, 19, 20, 19, 19, 19, 20, 19, 19, 19, 19, 19, 19, 19, 19, 19, 19, 19, 19, 19, 19, 19, 19, 20, 19, 19, 19, 19, 19, 19, 19, 19, 19, 18, 18, 18, 18, 19, 18, 18, 18, 18, 18, 18, 19, 18, 18, 18, 18, 19, 19, 18, 18, 18, 18, 18, 18, 18, 18, 18, 18, 18, 18, 18, 18, 18, 18, 18, 18, 18, 18, 18, 18, 18, 18, 18, 18, 18, 18, 18, 18, 17, 17, 17, 17, 17, 17, 17, 17, 17, 17, 17, 19, 18, 17, 17, 17, 18, 17, 17, 17, 17, 17, 17, 17, 17, 17, 17, 17, 18, 17, 17, 17, 17, 18, 17, 22, 18, 17,  ...

# %%
import pandas as pd

# Flatten the list of reviews and create a DataFrame
flattened_reviews = [review for sublist in reviews for review in sublist]
reviews_df = pd.DataFrame(flattened_reviews)

# Print the DataFrame to verify
print(reviews_df.head())

# View memory usage of the DataFrame
memory_usage_mb = reviews_df.memory_usage(deep=True).sum() / (1024 * 1024)  # Convert bytes to MB
print(f"Memory usage of reviews DataFrame: {memory_usage_mb:.2f} MB")

reviews_df.to_csv('RateMyProfAnalysis/UMassReviews/reviews.csv', index=False)
# Out:
#   attendanceMandatory     class  \
# 0       non mandatory  PSYCH100
# 1       non mandatory  PSYCH100
# 2       non mandatory  PSYCH370
# 3       non mandatory  PSYCH100
# 4       non mandatory       100
#
#                                              comment  createdByUser  \
# 0  Bickford was easily my favorite teacher. His l...          False
# 1  He might just be the most relatable and humoro...          False
# 2  exams are in person but are open note so just ...          False
# 3  hands down the BEST professor i've had here so...          False
# 4  Super funny guy, lectures are great. Gives LOT...          False
#
#                             date  difficultyRating  isForCredit  \
# 0  2025-01-13 18:51:48 +0000 UTC                 2         True
# 1  2024-12-24 23:27:46 +0000 UTC                 2         True
# 2  2024-12-16 02:54:06 +0000 UTC                 1         True
# 3  2024-12-09 23:44:58 +0000 UTC                 2         True
# 4  2024-12-07 00:00:23 +0000 UTC                 2         True
#
#    qualityRating  textbookUse  wouldTakeAgain     tid
# 0              5          3.0             1.0  203815
# 1              5          3.0             1.0  203815
# 2              5          3.0             1.0  203815
# 3              5          3.0             1.0  203815
# 4              5          3.0             1.0  203815
# Memory usage of reviews DataFrame: 24.28 MB

# %%
# Check for nulls and NaNs in the reviews DataFrame
nulls = reviews_df.isnull().sum()
print("Null values in reviews DataFrame:\n", nulls)

# Check for duplicates in the reviews DataFrame
duplicates = reviews_df.duplicated().sum()
print(f"Number of duplicate reviews: {duplicates}")

# Optionally, drop duplicates if needed
reviews_df = reviews_df.drop_duplicates()
# Out:
# Null values in reviews DataFrame:
#  attendanceMandatory        0
# class                      0
# comment                    0
# createdByUser              0
# date                       0
# difficultyRating           0
# isForCredit                0
# qualityRating              0
# textbookUse             9596
# wouldTakeAgain         29174
# tid                        0
# dtype: int64
# Number of duplicate reviews: 1

# %%
# Populate the existing professors dictionary
for review in flattened_reviews:
    tid = review['tid']
    quality_rating = review['qualityRating']
    difficulty_rating = review['difficultyRating']
    classs = review['class']  # Assuming 'class' is a field in the review

    # Update total reviews count
    if 'total_reviews_count' not in professor_dict[tid]:
        professor_dict[tid]['total_reviews_count'] = 0

    professor_dict[tid]['total_reviews_count'] += 1

    # Update average quality rating
    if 'average_quality_rating' not in professor_dict[tid]:
        professor_dict[tid]['average_quality_rating'] = 0
    professor_dict[tid]['average_quality_rating'] += quality_rating

    # Update average difficulty rating
    if 'average_difficulty_rating' not in professor_dict[tid]:
        professor_dict[tid]['average_difficulty_rating'] = 0
    professor_dict[tid]['average_difficulty_rating'] += difficulty_rating

    # Update classes taught
    if 'classes_taught' not in professor_dict[tid]:
        professor_dict[tid]['classes_taught'] = []
    if classs not in professor_dict[tid]['classes_taught']:
        professor_dict[tid]['classes_taught'].append(classs)

# Calculate the average ratings, wont work with subset of professors
for tid in professor_dict:
    if professor_dict[tid]['total_reviews_count'] > 0:
        professor_dict[tid]['average_quality_rating'] /= professor_dict[tid]['total_reviews_count']
        professor_dict[tid]['average_difficulty_rating'] /= professor_dict[tid]['total_reviews_count']
    professor_dict[tid]['classes_taught'] = list(professor_dict[tid]['classes_taught'])  # Convert set to list

# Convert the dictionary to a DataFrame
professors_df = pd.DataFrame.from_dict(professor_dict, orient='index').reset_index()
professors_df.rename(columns={'index': 'tid'}, inplace=True)
professors_df.drop('tid', axis=1, inplace=True)


# Save the professors DataFrame to a CSV file
professors_df.to_csv('RateMyProfAnalysis/UMassReviews/professors.csv', index=False)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[9], line 40
#      38 professors_df = pd.DataFrame.from_dict(professor_dict, orient='index').reset_index()
#      39 professors_df.rename(columns={'index': 'tid'}, inplace=True)
# ---> 40 professors_df.drop('tid')
#      43 # Save the professors DataFrame to a CSV file
#      44 professors_df.to_csv('RateMyProfAnalysis/UMassReviews/professors.csv', index=False)
#
# File ~\MLPractice\venvs\venv3.12\Lib\site-packages\pandas\core\frame.py:5581, in DataFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    5433 def drop(
#    5434     self,
#    5435     labels: IndexLabel | None = None,
#    (...)
#    5442     errors: IgnoreRaise = "raise",
#    5443 ) -> DataFrame | None:
#    5444     """
#    5445     Drop specified labels from rows or columns.
#    5446
#    (...)
#    5579             weight  1.0     0.8
#    5580     """
# -> 5581     return super().drop(
#    5582         labels=labels,
#    5583         axis=axis,
#    5584         index=index,
#    5585         columns=columns,
#    5586         level=level,
#    5587         inplace=inplace,
#    5588         errors=errors,
#    5589     )
#
# File ~\MLPractice\venvs\venv3.12\Lib\site-packages\pandas\core\generic.py:4788, in NDFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    4786 for axis, labels in axes.items():
#    4787     if labels is not None:
# -> 4788         obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    4790 if inplace:
#    4791     self._update_inplace(obj)
#
# File ~\MLPractice\venvs\venv3.12\Lib\site-packages\pandas\core\generic.py:4830, in NDFrame._drop_axis(self, labels, axis, level, errors, only_slice)
#    4828         new_axis = axis.drop(labels, level=level, errors=errors)
#    4829     else:
# -> 4830         new_axis = axis.drop(labels, errors=errors)
#    4831     indexer = axis.get_indexer(new_axis)
#    4833 # Case for non-unique axis
#    4834 else:
#
# File ~\MLPractice\venvs\venv3.12\Lib\site-packages\pandas\core\indexes\base.py:7070, in Index.drop(self, labels, errors)
#    7068 if mask.any():
#    7069     if errors != "ignore":
# -> 7070         raise KeyError(f"{labels[mask].tolist()} not found in axis")
#    7071     indexer = indexer[~mask]
#    7072 return self.delete(indexer)
#
# KeyError: "['tid'] not found in axis"

# %%
#TODO: Get more reviews from more colleges and then clean and post on kaggle
# Out:
#        tid       id                name   department  total_reviews_count  \
# 0   203815   203815       John Bickford   Psychology                  449
# 1    77120    77120     Randall Phillis      Biology                  388
# 2  1621419  1621419       Laura Francis      Biology                  370
# 3   192549   192549  Joanna Jeneralczuk  Mathematics                  323
# 4  1617241  1617241      Chris McDaniel    Chemistry                  298
#
#    average_quality_rating  average_difficulty_rating  \
# 0                4.077951                   2.031180
# 1                3.920103                   3.298969
# 2                2.659459                   4.000000
# 3                3.780186                   3.142415
# 4                2.104027                   4.342282
#
#                                       classes_taught
# 0  [PSYCH100, PSYCH370, 100, PSCYH100, PERSONALIT...
# 1  [BIO151, 151, 100, BIOLOGY151, BIO484, 101, IN...
# 2  [161H, BIO151, 285, BIO285, 151, BIO191, BIO15...
# 3  [STAT240, STAT501, STAT515, 240, STATS501, STA...
# 4  [CHEM269, CHEM261, CHEM266, CHEM262, CHEM265, ...
